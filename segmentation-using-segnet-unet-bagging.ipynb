# %% [markdown]
# ## Importing the Libraries

# %%
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, concatenate, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras import backend as K
from keras.layers.core import SpatialDropout2D
from keras.optimizers import Adam, SGD
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
plt.rcParams["axes.grid"] = False
np.random.seed(101)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx_ph2 = sorted(glob.glob('../input/*/*/trainx/*.bmp'), key=numericalSort)
X_train_ph2 = np.array([np.array(Image.open(fname)) for fname in filelist_trainx_ph2])

filelist_trainy_ph2 = sorted(glob.glob('../input/*/*/trainy/*.bmp'), key=numericalSort)
Y_train_ph2 = np.array([np.array(Image.open(fname)) for fname in filelist_trainy_ph2])

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.imshow(X_train_ph2[0])
plt.xlabel("Dimensions: "+str(np.array(X_train_ph2[0]).shape))
plt.subplot(1,2,2)
plt.imshow(Y_train_ph2[0], plt.cm.binary_r)
plt.xlabel("Dimensions: "+str(np.array(Y_train_ph2[0]).shape))
plt.show()

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
def resize(filename, size = (256,192)):
    im = Image.open(filename)
    im_resized = im.resize(size, Image.ANTIALIAS)
    return (im_resized)
#   im_resized.save('/resized_ph2/X_train/X_img_'+str(i)+'.bmp', dpi = (192,256))

# %%
X_train_ph2_resized = []
Y_train_ph2_resized = []

for i in range(len(filelist_trainx_ph2)):
    X_train_ph2_resized.append(resize(filelist_trainx_ph2[i]))
    Y_train_ph2_resized.append(resize(filelist_trainy_ph2[i]))

# %%
X_train_ph2 = np.array([np.array(img) for img in X_train_ph2_resized])
Y_train_ph2 = np.array([np.array(img) for img in Y_train_ph2_resized])

# %%
plt.figure(figsize=(12,6))
plt.suptitle("Images from PH2 dataset after resize")
plt.subplot(1,2,1)
plt.imshow(X_train_ph2[123])
plt.xlabel("Dimensions: "+str(np.array(X_train_ph2_resized[0]).shape))
plt.subplot(1,2,2)
plt.imshow(Y_train_ph2[123], plt.cm.binary_r)
plt.xlabel("Dimensions: "+str(np.array(Y_train_ph2_resized[0]).shape))
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train_ph2, Y_train_ph2, test_size = 0.25, random_state = 101)

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train_ph2[0])
plt.subplot(2,4,2)
plt.imshow(X_train_ph2[3])
plt.subplot(2,4,3)
plt.imshow(X_train_ph2[54])
plt.subplot(2,4,4)
plt.imshow(X_train_ph2[77])
plt.subplot(2,4,5)
plt.imshow(X_train_ph2[100])
plt.subplot(2,4,6)
plt.imshow(X_train_ph2[125])
plt.subplot(2,4,7)
plt.imshow(X_train_ph2[130])
plt.subplot(2,4,8)
plt.imshow(X_train_ph2[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train_ph2[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train_ph2[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train_ph2[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train_ph2[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train_ph2[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train_ph2[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train_ph2[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train_ph2[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining Evaluation Metrics

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac)

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
        return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)
x_rotated_t, y_rotated_t, x_flipped_t, y_flipped_t = img_augmentation(x_test, y_test)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 0
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,1,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
# For training Set
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 121
# Length of the Test Set       : 50
# Length of the Validation Set : 31

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# #### Optimizer and Learning Rate
# * We adopt SGD optimization algorithm, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * On large datasets, SGD can converge faster than batch training because it performs updates more frequently. We can get away with this because the data often contains redundant information, so the gradient can be reasonably approximated without using the full dataset. Minibatch training can be faster than training on single data points because it can take advantage of vectorized operations to process the entire minibatch at once. The stochastic nature of online/minibatch training can also make it possible to hop out of local minima that might otherwise trap batch training.
# * The learning rate is the conventional 0.001.

# %% [markdown]
# ### Model Function

# %% [markdown]
# ![arch](https://www.researchgate.net/profile/Adam_Czajka2/publication/326151825/figure/fig2/AS:647447659438083@1531374959468/Encoder-decoder-architecture-of-SegNet-Inference-takes-place-from-left-to-right-Size-of.png)

# %% [markdown]
# * The architecture we are implementing is suggested in [this](https://arxiv.org/pdf/1511.00561.pdf) paper.
# * The advised parameters can't exactly be applied to our problem.
# * We will switch the final activation function from **Softmax** to **Sigmoid** as using softmax was producing blank dark images.
# * The loss function in segnet is suggested **categorical crossentropy** due to it's genral use of muliclass segmentation problem but in our case we only have 1 class i.e. the melanoma. So, we will use **binary crossentropy**

# %% [markdown]
# ## Loading the Model

# %% [markdown]
# ### Unet Model

# %%
# Number of image channels (for example 3 in case of RGB, or 1 for grayscale images)
INPUT_CHANNELS = 3
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
# Pretrained weights

# %%
def double_conv_layer(x, size, dropout=0.40, batch_norm=True):
    if K.common.image_dim_ordering() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = SpatialDropout2D(dropout)(conv)
    return conv


def UNET(epochs_num, savename):
    dropout_val=0.50
    if K.common.image_dim_ordering() == 'th':
        inputs = Input((INPUT_CHANNELS, 192, 256))
        axis = 1
    else:
        inputs = Input((192, 256, INPUT_CHANNELS))
        axis = 3
    filters = 32

    conv_224 = double_conv_layer(inputs, filters)
    pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

    conv_112 = double_conv_layer(pool_112, 2*filters)
    pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

    conv_56 = double_conv_layer(pool_56, 4*filters)
    pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

    conv_28 = double_conv_layer(pool_28, 8*filters)
    pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

    conv_14 = double_conv_layer(pool_14, 16*filters)
    pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

    conv_7 = double_conv_layer(pool_7, 32*filters)

    up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
    up_conv_14 = double_conv_layer(up_14, 16*filters)

    up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
    up_conv_28 = double_conv_layer(up_28, 8*filters)

    up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
    up_conv_56 = double_conv_layer(up_56, 4*filters)

    up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
    up_conv_112 = double_conv_layer(up_112, 2*filters)

    up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
    up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

    conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
    conv_final = Activation('sigmoid')(conv_final)
    pred = Reshape((192, 256))(conv_final)
    model = Model(inputs, pred, name="UNET_224")
    model.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coef, precision, recall, accuracy])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18,validation_data=(x_val, y_val), verbose=1)
    model.save(savename)
    return model, hist

# %%
model, hist = UNET(epochs_num= 100, savename= 'unet_100_epoch.h5')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 192, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 192, 256, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 192, 256, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 192, 256, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 192, 256, 32) 9248        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 192, 256, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 192, 256, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_1 (SpatialDro (None, 192, 256, 32) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 96, 128, 32)  0           spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 96, 128, 64)  18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 96, 128, 64)  256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 96, 128, 64)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 96, 128, 64)  36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 96, 128, 64)  256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 96, 128, 64)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_2 (SpatialDro (None, 96, 128, 64)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 48, 64, 64)   0           spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 48, 64, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 48, 64, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 48, 64, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 48, 64, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 48, 64, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 48, 64, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_3 (SpatialDro (None, 48, 64, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 24, 32, 128)  0           spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 24, 32, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 24, 32, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 24, 32, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 24, 32, 256)  590080      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 24, 32, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 24, 32, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_4 (SpatialDro (None, 24, 32, 256)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 12, 16, 256)  0           spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 12, 16, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 12, 16, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 12, 16, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 12, 16, 512)  2359808     activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 12, 16, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 12, 16, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_5 (SpatialDro (None, 12, 16, 512)  0           activation_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 6, 8, 512)    0           spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 6, 8, 1024)   4719616     max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 6, 8, 1024)   4096        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 6, 8, 1024)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 6, 8, 1024)   9438208     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 6, 8, 1024)   4096        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 6, 8, 1024)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_6 (SpatialDro (None, 6, 8, 1024)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 12, 16, 1024) 0           spatial_dropout2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 16, 1536) 0           up_sampling2d_1[0][0]
#                                                                  spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 12, 16, 512)  7078400     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 12, 16, 512)  2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 12, 16, 512)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 12, 16, 512)  2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 12, 16, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 12, 16, 512)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_7 (SpatialDro (None, 12, 16, 512)  0           activation_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 24, 32, 512)  0           spatial_dropout2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 24, 32, 768)  0           up_sampling2d_2[0][0]
#                                                                  spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 24, 32, 256)  1769728     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 24, 32, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 24, 32, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 24, 32, 256)  590080      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 24, 32, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 24, 32, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_8 (SpatialDro (None, 24, 32, 256)  0           activation_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 48, 64, 256)  0           spatial_dropout2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 48, 64, 384)  0           up_sampling2d_3[0][0]
#                                                                  spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 48, 64, 128)  442496      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 48, 64, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 48, 64, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 48, 64, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 48, 64, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 48, 64, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_9 (SpatialDro (None, 48, 64, 128)  0           activation_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 96, 128, 128) 0           spatial_dropout2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 96, 128, 192) 0           up_sampling2d_4[0][0]
#                                                                  spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 96, 128, 64)  110656      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 96, 128, 64)  256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 96, 128, 64)  0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 96, 128, 64)  36928       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 96, 128, 64)  256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 96, 128, 64)  0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10 (SpatialDr (None, 96, 128, 64)  0           activation_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 192, 256, 64) 0           spatial_dropout2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 192, 256, 96) 0           up_sampling2d_5[0][0]
#                                                                  spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 192, 256, 32) 27680       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 192, 256, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 192, 256, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 192, 256, 32) 9248        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 192, 256, 32) 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 192, 256, 32) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_11 (SpatialDr (None, 192, 256, 32) 0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 192, 256, 1)  33          spatial_dropout2d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 192, 256, 1)  0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 192, 256)     0           activation_23[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# Train on 121 samples, validate on 31 samples
# Epoch 1/100
# 121/121 [==============================] - 13s 110ms/step - loss: 0.2340 - iou: 0.7660 - dice_coef: 0.5057 - precision: 0.5848 - recall: 0.5560 - accuracy: 0.7418 - val_loss: 0.4551 - val_iou: 0.5449 - val_dice_coef: 0.5292 - val_precision: 0.3643 - val_recall: 0.9968 - val_accuracy: 0.3687
# Epoch 2/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.1654 - iou: 0.8346 - dice_coef: 0.6300 - precision: 0.7065 - recall: 0.6889 - accuracy: 0.8119 - val_loss: 0.4587 - val_iou: 0.5413 - val_dice_coef: 0.5274 - val_precision: 0.3621 - val_recall: 1.0000 - val_accuracy: 0.3621
# Epoch 3/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.1340 - iou: 0.8660 - dice_coef: 0.6932 - precision: 0.8058 - recall: 0.7217 - accuracy: 0.8569 - val_loss: 0.4582 - val_iou: 0.5418 - val_dice_coef: 0.5277 - val_precision: 0.3623 - val_recall: 0.9998 - val_accuracy: 0.3628
# Epoch 4/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.1334 - iou: 0.8666 - dice_coef: 0.7063 - precision: 0.7879 - recall: 0.7550 - accuracy: 0.8569 - val_loss: 0.4571 - val_iou: 0.5429 - val_dice_coef: 0.5282 - val_precision: 0.3628 - val_recall: 0.9987 - val_accuracy: 0.3648
# Epoch 5/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.1245 - iou: 0.8755 - dice_coef: 0.7137 - precision: 0.8056 - recall: 0.7560 - accuracy: 0.8642 - val_loss: 0.4413 - val_iou: 0.5587 - val_dice_coef: 0.5329 - val_precision: 0.3693 - val_recall: 0.9783 - val_accuracy: 0.3923
# Epoch 6/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.1099 - iou: 0.8901 - dice_coef: 0.7396 - precision: 0.8550 - recall: 0.7847 - accuracy: 0.8888 - val_loss: 0.4318 - val_iou: 0.5682 - val_dice_coef: 0.5328 - val_precision: 0.3740 - val_recall: 0.9334 - val_accuracy: 0.4205
# Epoch 7/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.1004 - iou: 0.8996 - dice_coef: 0.7544 - precision: 0.8766 - recall: 0.7840 - accuracy: 0.8986 - val_loss: 0.3048 - val_iou: 0.6952 - val_dice_coef: 0.6208 - val_precision: 0.4793 - val_recall: 0.9049 - val_accuracy: 0.6215
# Epoch 8/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0925 - iou: 0.9075 - dice_coef: 0.7784 - precision: 0.8372 - recall: 0.8458 - accuracy: 0.8987 - val_loss: 0.4171 - val_iou: 0.5829 - val_dice_coef: 0.5580 - val_precision: 0.3909 - val_recall: 0.9874 - val_accuracy: 0.4474
# Epoch 9/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.1120 - iou: 0.8880 - dice_coef: 0.7388 - precision: 0.8169 - recall: 0.8047 - accuracy: 0.8800 - val_loss: 0.2948 - val_iou: 0.7052 - val_dice_coef: 0.6233 - val_precision: 0.4867 - val_recall: 0.8862 - val_accuracy: 0.6341
# Epoch 10/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.1028 - iou: 0.8972 - dice_coef: 0.7659 - precision: 0.8497 - recall: 0.8137 - accuracy: 0.8968 - val_loss: 0.2451 - val_iou: 0.7549 - val_dice_coef: 0.6572 - val_precision: 0.5499 - val_recall: 0.8474 - val_accuracy: 0.7062
# Epoch 11/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0911 - iou: 0.9089 - dice_coef: 0.7832 - precision: 0.8751 - recall: 0.8191 - accuracy: 0.9066 - val_loss: 0.1610 - val_iou: 0.8390 - val_dice_coef: 0.7386 - val_precision: 0.6914 - val_recall: 0.8463 - val_accuracy: 0.8128
# Epoch 12/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.1084 - iou: 0.8916 - dice_coef: 0.7668 - precision: 0.8258 - recall: 0.8138 - accuracy: 0.8841 - val_loss: 0.2036 - val_iou: 0.7964 - val_dice_coef: 0.7126 - val_precision: 0.6042 - val_recall: 0.9000 - val_accuracy: 0.7586
# Epoch 13/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0997 - iou: 0.9003 - dice_coef: 0.7696 - precision: 0.8757 - recall: 0.7829 - accuracy: 0.8916 - val_loss: 0.1941 - val_iou: 0.8059 - val_dice_coef: 0.6869 - val_precision: 0.6814 - val_recall: 0.7192 - val_accuracy: 0.7790
# Epoch 14/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0942 - iou: 0.9058 - dice_coef: 0.7787 - precision: 0.8915 - recall: 0.8029 - accuracy: 0.9064 - val_loss: 0.2138 - val_iou: 0.7862 - val_dice_coef: 0.6892 - val_precision: 0.6050 - val_recall: 0.8184 - val_accuracy: 0.7491
# Epoch 15/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0994 - iou: 0.9006 - dice_coef: 0.7765 - precision: 0.8383 - recall: 0.8348 - accuracy: 0.8955 - val_loss: 0.1971 - val_iou: 0.8029 - val_dice_coef: 0.5483 - val_precision: 0.9724 - val_recall: 0.3735 - val_accuracy: 0.7642
# Epoch 16/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0987 - iou: 0.9013 - dice_coef: 0.7763 - precision: 0.8926 - recall: 0.7764 - accuracy: 0.8969 - val_loss: 0.1654 - val_iou: 0.8346 - val_dice_coef: 0.7524 - val_precision: 0.7067 - val_recall: 0.8289 - val_accuracy: 0.8189
# Epoch 17/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0927 - iou: 0.9073 - dice_coef: 0.7899 - precision: 0.8894 - recall: 0.8073 - accuracy: 0.9050 - val_loss: 0.2629 - val_iou: 0.7371 - val_dice_coef: 0.6566 - val_precision: 0.5153 - val_recall: 0.9091 - val_accuracy: 0.6727
# Epoch 18/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0934 - iou: 0.9066 - dice_coef: 0.7935 - precision: 0.8761 - recall: 0.8121 - accuracy: 0.9042 - val_loss: 0.2610 - val_iou: 0.7390 - val_dice_coef: 0.6731 - val_precision: 0.5261 - val_recall: 0.9464 - val_accuracy: 0.6836
# Epoch 19/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0850 - iou: 0.9150 - dice_coef: 0.8106 - precision: 0.8829 - recall: 0.8350 - accuracy: 0.9130 - val_loss: 0.3523 - val_iou: 0.6477 - val_dice_coef: 0.6123 - val_precision: 0.4413 - val_recall: 0.9959 - val_accuracy: 0.5476
# Epoch 20/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0869 - iou: 0.9131 - dice_coef: 0.7954 - precision: 0.8977 - recall: 0.8188 - accuracy: 0.9134 - val_loss: 0.2468 - val_iou: 0.7532 - val_dice_coef: 0.6883 - val_precision: 0.5425 - val_recall: 0.9712 - val_accuracy: 0.7023
# Epoch 21/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0946 - iou: 0.9054 - dice_coef: 0.7836 - precision: 0.8578 - recall: 0.8211 - accuracy: 0.8980 - val_loss: 0.1166 - val_iou: 0.8834 - val_dice_coef: 0.7894 - val_precision: 0.8444 - val_recall: 0.7634 - val_accuracy: 0.8686
# Epoch 22/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0839 - iou: 0.9161 - dice_coef: 0.8086 - precision: 0.9112 - recall: 0.8121 - accuracy: 0.9145 - val_loss: 0.1355 - val_iou: 0.8645 - val_dice_coef: 0.7728 - val_precision: 0.8018 - val_recall: 0.7617 - val_accuracy: 0.8510
# Epoch 23/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0808 - iou: 0.9192 - dice_coef: 0.8172 - precision: 0.9010 - recall: 0.8297 - accuracy: 0.9166 - val_loss: 0.1441 - val_iou: 0.8559 - val_dice_coef: 0.7674 - val_precision: 0.7155 - val_recall: 0.8386 - val_accuracy: 0.8332
# Epoch 24/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0829 - iou: 0.9171 - dice_coef: 0.8142 - precision: 0.8649 - recall: 0.8621 - accuracy: 0.9139 - val_loss: 0.2597 - val_iou: 0.7403 - val_dice_coef: 0.6735 - val_precision: 0.5336 - val_recall: 0.9228 - val_accuracy: 0.6937
# Epoch 25/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0857 - iou: 0.9143 - dice_coef: 0.8031 - precision: 0.9022 - recall: 0.8091 - accuracy: 0.9089 - val_loss: 0.1897 - val_iou: 0.8103 - val_dice_coef: 0.7290 - val_precision: 0.6432 - val_recall: 0.8495 - val_accuracy: 0.7863
# Epoch 26/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0837 - iou: 0.9163 - dice_coef: 0.8041 - precision: 0.9035 - recall: 0.8084 - accuracy: 0.9106 - val_loss: 0.1387 - val_iou: 0.8613 - val_dice_coef: 0.7743 - val_precision: 0.8174 - val_recall: 0.7499 - val_accuracy: 0.8552
# Epoch 27/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0935 - iou: 0.9065 - dice_coef: 0.7855 - precision: 0.8689 - recall: 0.8324 - accuracy: 0.9029 - val_loss: 0.1372 - val_iou: 0.8628 - val_dice_coef: 0.7799 - val_precision: 0.7745 - val_recall: 0.8000 - val_accuracy: 0.8521
# Epoch 28/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0803 - iou: 0.9197 - dice_coef: 0.8190 - precision: 0.8837 - recall: 0.8467 - accuracy: 0.9172 - val_loss: 0.1349 - val_iou: 0.8651 - val_dice_coef: 0.7462 - val_precision: 0.9395 - val_recall: 0.6394 - val_accuracy: 0.8547
# Epoch 29/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0759 - iou: 0.9241 - dice_coef: 0.8387 - precision: 0.8626 - recall: 0.8752 - accuracy: 0.9167 - val_loss: 0.1135 - val_iou: 0.8865 - val_dice_coef: 0.7928 - val_precision: 0.9173 - val_recall: 0.7220 - val_accuracy: 0.8763
# Epoch 30/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0771 - iou: 0.9229 - dice_coef: 0.8285 - precision: 0.8730 - recall: 0.8659 - accuracy: 0.9176 - val_loss: 0.1108 - val_iou: 0.8892 - val_dice_coef: 0.8184 - val_precision: 0.8105 - val_recall: 0.8394 - val_accuracy: 0.8737
# Epoch 31/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0807 - iou: 0.9193 - dice_coef: 0.8107 - precision: 0.9140 - recall: 0.8165 - accuracy: 0.9147 - val_loss: 0.1050 - val_iou: 0.8950 - val_dice_coef: 0.8306 - val_precision: 0.8646 - val_recall: 0.8269 - val_accuracy: 0.8925
# Epoch 32/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0788 - iou: 0.9212 - dice_coef: 0.8176 - precision: 0.9015 - recall: 0.8202 - accuracy: 0.9156 - val_loss: 0.1043 - val_iou: 0.8957 - val_dice_coef: 0.8243 - val_precision: 0.8444 - val_recall: 0.8234 - val_accuracy: 0.8864
# Epoch 33/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0825 - iou: 0.9175 - dice_coef: 0.8176 - precision: 0.8620 - recall: 0.8618 - accuracy: 0.9140 - val_loss: 0.1315 - val_iou: 0.8685 - val_dice_coef: 0.7537 - val_precision: 0.9637 - val_recall: 0.6327 - val_accuracy: 0.8570
# Epoch 34/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0710 - iou: 0.9290 - dice_coef: 0.8353 - precision: 0.9241 - recall: 0.8430 - accuracy: 0.9275 - val_loss: 0.1279 - val_iou: 0.8721 - val_dice_coef: 0.7578 - val_precision: 0.9722 - val_recall: 0.6283 - val_accuracy: 0.8566
# Epoch 35/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0745 - iou: 0.9255 - dice_coef: 0.8350 - precision: 0.8941 - recall: 0.8496 - accuracy: 0.9207 - val_loss: 0.0982 - val_iou: 0.9018 - val_dice_coef: 0.8239 - val_precision: 0.8698 - val_recall: 0.8014 - val_accuracy: 0.8896
# Epoch 36/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0822 - iou: 0.9178 - dice_coef: 0.8227 - precision: 0.8839 - recall: 0.8289 - accuracy: 0.9122 - val_loss: 0.1040 - val_iou: 0.8960 - val_dice_coef: 0.8256 - val_precision: 0.8821 - val_recall: 0.7985 - val_accuracy: 0.8889
# Epoch 37/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0717 - iou: 0.9283 - dice_coef: 0.8313 - precision: 0.9344 - recall: 0.8272 - accuracy: 0.9254 - val_loss: 0.1085 - val_iou: 0.8915 - val_dice_coef: 0.8006 - val_precision: 0.8918 - val_recall: 0.7585 - val_accuracy: 0.8805
# Epoch 38/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0744 - iou: 0.9256 - dice_coef: 0.8263 - precision: 0.9137 - recall: 0.8467 - accuracy: 0.9253 - val_loss: 0.1215 - val_iou: 0.8785 - val_dice_coef: 0.7890 - val_precision: 0.8277 - val_recall: 0.7991 - val_accuracy: 0.8655
# Epoch 39/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0804 - iou: 0.9196 - dice_coef: 0.8251 - precision: 0.8972 - recall: 0.8349 - accuracy: 0.9173 - val_loss: 0.1549 - val_iou: 0.8451 - val_dice_coef: 0.7495 - val_precision: 0.7727 - val_recall: 0.7721 - val_accuracy: 0.8293
# Epoch 40/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0799 - iou: 0.9201 - dice_coef: 0.8245 - precision: 0.8981 - recall: 0.8368 - accuracy: 0.9164 - val_loss: 0.1823 - val_iou: 0.8177 - val_dice_coef: 0.7121 - val_precision: 0.7368 - val_recall: 0.7404 - val_accuracy: 0.8031
# Epoch 41/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0762 - iou: 0.9238 - dice_coef: 0.8252 - precision: 0.9054 - recall: 0.8445 - accuracy: 0.9221 - val_loss: 0.1423 - val_iou: 0.8577 - val_dice_coef: 0.7558 - val_precision: 0.7799 - val_recall: 0.7614 - val_accuracy: 0.8393
# Epoch 42/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0753 - iou: 0.9247 - dice_coef: 0.8286 - precision: 0.9159 - recall: 0.8447 - accuracy: 0.9257 - val_loss: 0.1086 - val_iou: 0.8914 - val_dice_coef: 0.8266 - val_precision: 0.7710 - val_recall: 0.9136 - val_accuracy: 0.8760
# Epoch 43/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0685 - iou: 0.9315 - dice_coef: 0.8514 - precision: 0.8919 - recall: 0.8770 - accuracy: 0.9283 - val_loss: 0.0914 - val_iou: 0.9086 - val_dice_coef: 0.8409 - val_precision: 0.8144 - val_recall: 0.9101 - val_accuracy: 0.8961
# Epoch 44/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0739 - iou: 0.9261 - dice_coef: 0.8401 - precision: 0.8999 - recall: 0.8535 - accuracy: 0.9242 - val_loss: 0.0815 - val_iou: 0.9185 - val_dice_coef: 0.8420 - val_precision: 0.9132 - val_recall: 0.8204 - val_accuracy: 0.9081
# Epoch 45/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0660 - iou: 0.9340 - dice_coef: 0.8504 - precision: 0.9186 - recall: 0.8572 - accuracy: 0.9305 - val_loss: 0.0817 - val_iou: 0.9183 - val_dice_coef: 0.8346 - val_precision: 0.9024 - val_recall: 0.8219 - val_accuracy: 0.9053
# Epoch 46/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0775 - iou: 0.9225 - dice_coef: 0.8331 - precision: 0.8782 - recall: 0.8602 - accuracy: 0.9187 - val_loss: 0.0989 - val_iou: 0.9011 - val_dice_coef: 0.8235 - val_precision: 0.7922 - val_recall: 0.8769 - val_accuracy: 0.8780
# Epoch 47/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0725 - iou: 0.9275 - dice_coef: 0.8407 - precision: 0.9295 - recall: 0.8237 - accuracy: 0.9242 - val_loss: 0.1028 - val_iou: 0.8972 - val_dice_coef: 0.8371 - val_precision: 0.7848 - val_recall: 0.9173 - val_accuracy: 0.8844
# Epoch 48/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0683 - iou: 0.9317 - dice_coef: 0.8416 - precision: 0.9410 - recall: 0.8231 - accuracy: 0.9277 - val_loss: 0.1107 - val_iou: 0.8893 - val_dice_coef: 0.8125 - val_precision: 0.7745 - val_recall: 0.8658 - val_accuracy: 0.8700
# Epoch 49/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0749 - iou: 0.9251 - dice_coef: 0.8386 - precision: 0.8837 - recall: 0.8775 - accuracy: 0.9239 - val_loss: 0.1088 - val_iou: 0.8912 - val_dice_coef: 0.8073 - val_precision: 0.7907 - val_recall: 0.8368 - val_accuracy: 0.8703
# Epoch 50/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0779 - iou: 0.9221 - dice_coef: 0.8336 - precision: 0.8926 - recall: 0.8400 - accuracy: 0.9165 - val_loss: 0.1023 - val_iou: 0.8977 - val_dice_coef: 0.8140 - val_precision: 0.8984 - val_recall: 0.7699 - val_accuracy: 0.8896
# Epoch 51/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0790 - iou: 0.9210 - dice_coef: 0.8190 - precision: 0.9380 - recall: 0.7925 - accuracy: 0.9183 - val_loss: 0.0964 - val_iou: 0.9036 - val_dice_coef: 0.8128 - val_precision: 0.9638 - val_recall: 0.7264 - val_accuracy: 0.8921
# Epoch 52/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0740 - iou: 0.9260 - dice_coef: 0.8335 - precision: 0.8990 - recall: 0.8686 - accuracy: 0.9264 - val_loss: 0.0885 - val_iou: 0.9115 - val_dice_coef: 0.8260 - val_precision: 0.9699 - val_recall: 0.7420 - val_accuracy: 0.9000
# Epoch 53/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0695 - iou: 0.9305 - dice_coef: 0.8516 - precision: 0.9092 - recall: 0.8551 - accuracy: 0.9284 - val_loss: 0.0910 - val_iou: 0.9090 - val_dice_coef: 0.8292 - val_precision: 0.9384 - val_recall: 0.7753 - val_accuracy: 0.9021
# Epoch 54/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0694 - iou: 0.9306 - dice_coef: 0.8488 - precision: 0.9311 - recall: 0.8337 - accuracy: 0.9282 - val_loss: 0.0894 - val_iou: 0.9106 - val_dice_coef: 0.8366 - val_precision: 0.8735 - val_recall: 0.8411 - val_accuracy: 0.9031
# Epoch 55/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0771 - iou: 0.9229 - dice_coef: 0.8260 - precision: 0.9000 - recall: 0.8430 - accuracy: 0.9196 - val_loss: 0.1105 - val_iou: 0.8895 - val_dice_coef: 0.7871 - val_precision: 0.9552 - val_recall: 0.6973 - val_accuracy: 0.8822
# Epoch 56/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0661 - iou: 0.9339 - dice_coef: 0.8533 - precision: 0.9239 - recall: 0.8633 - accuracy: 0.9348 - val_loss: 0.1021 - val_iou: 0.8979 - val_dice_coef: 0.8124 - val_precision: 0.9740 - val_recall: 0.7065 - val_accuracy: 0.8885
# Epoch 57/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0755 - iou: 0.9245 - dice_coef: 0.8377 - precision: 0.8912 - recall: 0.8526 - accuracy: 0.9206 - val_loss: 0.0781 - val_iou: 0.9219 - val_dice_coef: 0.8573 - val_precision: 0.9174 - val_recall: 0.8203 - val_accuracy: 0.9125
# Epoch 58/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0709 - iou: 0.9291 - dice_coef: 0.8450 - precision: 0.8891 - recall: 0.8707 - accuracy: 0.9252 - val_loss: 0.0798 - val_iou: 0.9202 - val_dice_coef: 0.8603 - val_precision: 0.9027 - val_recall: 0.8354 - val_accuracy: 0.9124
# Epoch 59/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0760 - iou: 0.9240 - dice_coef: 0.8368 - precision: 0.8943 - recall: 0.8401 - accuracy: 0.9192 - val_loss: 0.0843 - val_iou: 0.9157 - val_dice_coef: 0.8526 - val_precision: 0.9515 - val_recall: 0.7799 - val_accuracy: 0.9095
# Epoch 60/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0734 - iou: 0.9266 - dice_coef: 0.8348 - precision: 0.9306 - recall: 0.8264 - accuracy: 0.9242 - val_loss: 0.0740 - val_iou: 0.9260 - val_dice_coef: 0.8650 - val_precision: 0.9582 - val_recall: 0.8000 - val_accuracy: 0.9179
# Epoch 61/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0697 - iou: 0.9303 - dice_coef: 0.8458 - precision: 0.9014 - recall: 0.8649 - accuracy: 0.9267 - val_loss: 0.0655 - val_iou: 0.9345 - val_dice_coef: 0.8773 - val_precision: 0.9251 - val_recall: 0.8752 - val_accuracy: 0.9314
# Epoch 62/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0693 - iou: 0.9307 - dice_coef: 0.8529 - precision: 0.8999 - recall: 0.8735 - accuracy: 0.9287 - val_loss: 0.0719 - val_iou: 0.9281 - val_dice_coef: 0.8707 - val_precision: 0.8943 - val_recall: 0.8880 - val_accuracy: 0.9240
# Epoch 63/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0699 - iou: 0.9301 - dice_coef: 0.8464 - precision: 0.9076 - recall: 0.8565 - accuracy: 0.9258 - val_loss: 0.0933 - val_iou: 0.9067 - val_dice_coef: 0.8295 - val_precision: 0.9392 - val_recall: 0.7637 - val_accuracy: 0.8974
# Epoch 64/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0698 - iou: 0.9302 - dice_coef: 0.8434 - precision: 0.9305 - recall: 0.8388 - accuracy: 0.9274 - val_loss: 0.0886 - val_iou: 0.9114 - val_dice_coef: 0.8241 - val_precision: 0.9637 - val_recall: 0.7429 - val_accuracy: 0.8986
# Epoch 65/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0719 - iou: 0.9281 - dice_coef: 0.8363 - precision: 0.8996 - recall: 0.8575 - accuracy: 0.9252 - val_loss: 0.0825 - val_iou: 0.9175 - val_dice_coef: 0.8402 - val_precision: 0.9147 - val_recall: 0.8266 - val_accuracy: 0.9121
# Epoch 66/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0631 - iou: 0.9369 - dice_coef: 0.8552 - precision: 0.9284 - recall: 0.8657 - accuracy: 0.9359 - val_loss: 0.0727 - val_iou: 0.9273 - val_dice_coef: 0.8578 - val_precision: 0.9351 - val_recall: 0.8318 - val_accuracy: 0.9219
# Epoch 67/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0693 - iou: 0.9307 - dice_coef: 0.8476 - precision: 0.9244 - recall: 0.8458 - accuracy: 0.9267 - val_loss: 0.1171 - val_iou: 0.8829 - val_dice_coef: 0.7826 - val_precision: 0.8323 - val_recall: 0.7797 - val_accuracy: 0.8701
# Epoch 68/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0747 - iou: 0.9253 - dice_coef: 0.8454 - precision: 0.8778 - recall: 0.8797 - accuracy: 0.9225 - val_loss: 0.1289 - val_iou: 0.8711 - val_dice_coef: 0.7739 - val_precision: 0.8061 - val_recall: 0.7915 - val_accuracy: 0.8560
# Epoch 69/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0691 - iou: 0.9309 - dice_coef: 0.8520 - precision: 0.8982 - recall: 0.8823 - accuracy: 0.9301 - val_loss: 0.0871 - val_iou: 0.9129 - val_dice_coef: 0.8295 - val_precision: 0.9416 - val_recall: 0.7676 - val_accuracy: 0.9005
# Epoch 70/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0711 - iou: 0.9289 - dice_coef: 0.8367 - precision: 0.9144 - recall: 0.8405 - accuracy: 0.9243 - val_loss: 0.0831 - val_iou: 0.9169 - val_dice_coef: 0.8550 - val_precision: 0.9350 - val_recall: 0.8064 - val_accuracy: 0.9111
# Epoch 71/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0738 - iou: 0.9262 - dice_coef: 0.8347 - precision: 0.9044 - recall: 0.8428 - accuracy: 0.9212 - val_loss: 0.2416 - val_iou: 0.7584 - val_dice_coef: 0.5042 - val_precision: 0.9861 - val_recall: 0.3469 - val_accuracy: 0.7631
# Epoch 72/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0669 - iou: 0.9331 - dice_coef: 0.8472 - precision: 0.9102 - recall: 0.8704 - accuracy: 0.9310 - val_loss: 0.1553 - val_iou: 0.8447 - val_dice_coef: 0.6938 - val_precision: 0.9831 - val_recall: 0.5532 - val_accuracy: 0.8379
# Epoch 73/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0777 - iou: 0.9223 - dice_coef: 0.8317 - precision: 0.8972 - recall: 0.8452 - accuracy: 0.9200 - val_loss: 0.0908 - val_iou: 0.9092 - val_dice_coef: 0.8229 - val_precision: 0.9541 - val_recall: 0.7430 - val_accuracy: 0.8956
# Epoch 74/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0692 - iou: 0.9308 - dice_coef: 0.8466 - precision: 0.9150 - recall: 0.8496 - accuracy: 0.9273 - val_loss: 0.0822 - val_iou: 0.9178 - val_dice_coef: 0.8458 - val_precision: 0.9249 - val_recall: 0.8035 - val_accuracy: 0.9065
# Epoch 75/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0627 - iou: 0.9373 - dice_coef: 0.8627 - precision: 0.9290 - recall: 0.8679 - accuracy: 0.9368 - val_loss: 0.0743 - val_iou: 0.9257 - val_dice_coef: 0.8584 - val_precision: 0.9350 - val_recall: 0.8230 - val_accuracy: 0.9179
# Epoch 76/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0764 - iou: 0.9236 - dice_coef: 0.8431 - precision: 0.8728 - recall: 0.8678 - accuracy: 0.9186 - val_loss: 0.0779 - val_iou: 0.9221 - val_dice_coef: 0.8518 - val_precision: 0.9329 - val_recall: 0.8094 - val_accuracy: 0.9137
# Epoch 77/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0671 - iou: 0.9329 - dice_coef: 0.8551 - precision: 0.9274 - recall: 0.8503 - accuracy: 0.9304 - val_loss: 0.0924 - val_iou: 0.9076 - val_dice_coef: 0.8503 - val_precision: 0.8424 - val_recall: 0.8810 - val_accuracy: 0.9033
# Epoch 78/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0654 - iou: 0.9346 - dice_coef: 0.8503 - precision: 0.9199 - recall: 0.8629 - accuracy: 0.9322 - val_loss: 0.1399 - val_iou: 0.8601 - val_dice_coef: 0.7709 - val_precision: 0.8749 - val_recall: 0.7073 - val_accuracy: 0.8602
# Epoch 79/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0663 - iou: 0.9337 - dice_coef: 0.8551 - precision: 0.9092 - recall: 0.8712 - accuracy: 0.9323 - val_loss: 0.0799 - val_iou: 0.9201 - val_dice_coef: 0.8520 - val_precision: 0.9697 - val_recall: 0.7697 - val_accuracy: 0.9111
# Epoch 80/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0690 - iou: 0.9310 - dice_coef: 0.8487 - precision: 0.9155 - recall: 0.8576 - accuracy: 0.9295 - val_loss: 0.0781 - val_iou: 0.9219 - val_dice_coef: 0.8508 - val_precision: 0.9717 - val_recall: 0.7701 - val_accuracy: 0.9111
# Epoch 81/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0705 - iou: 0.9295 - dice_coef: 0.8522 - precision: 0.9212 - recall: 0.8526 - accuracy: 0.9282 - val_loss: 0.0901 - val_iou: 0.9099 - val_dice_coef: 0.8268 - val_precision: 0.9633 - val_recall: 0.7397 - val_accuracy: 0.8957
# Epoch 82/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0699 - iou: 0.9301 - dice_coef: 0.8494 - precision: 0.9126 - recall: 0.8536 - accuracy: 0.9273 - val_loss: 0.0907 - val_iou: 0.9093 - val_dice_coef: 0.8274 - val_precision: 0.9565 - val_recall: 0.7570 - val_accuracy: 0.8996
# Epoch 83/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0672 - iou: 0.9328 - dice_coef: 0.8563 - precision: 0.8931 - recall: 0.8861 - accuracy: 0.9297 - val_loss: 0.0825 - val_iou: 0.9175 - val_dice_coef: 0.8420 - val_precision: 0.9682 - val_recall: 0.7644 - val_accuracy: 0.9069
# Epoch 84/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0677 - iou: 0.9323 - dice_coef: 0.8486 - precision: 0.9108 - recall: 0.8642 - accuracy: 0.9285 - val_loss: 0.0885 - val_iou: 0.9115 - val_dice_coef: 0.8325 - val_precision: 0.9809 - val_recall: 0.7383 - val_accuracy: 0.9034
# Epoch 85/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0642 - iou: 0.9358 - dice_coef: 0.8574 - precision: 0.9357 - recall: 0.8462 - accuracy: 0.9341 - val_loss: 0.0583 - val_iou: 0.9417 - val_dice_coef: 0.8928 - val_precision: 0.9475 - val_recall: 0.8666 - val_accuracy: 0.9365
# Epoch 86/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0617 - iou: 0.9383 - dice_coef: 0.8640 - precision: 0.9053 - recall: 0.8884 - accuracy: 0.9352 - val_loss: 0.0669 - val_iou: 0.9331 - val_dice_coef: 0.8769 - val_precision: 0.9223 - val_recall: 0.8654 - val_accuracy: 0.9267
# Epoch 87/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0628 - iou: 0.9372 - dice_coef: 0.8630 - precision: 0.9080 - recall: 0.8886 - accuracy: 0.9349 - val_loss: 0.0629 - val_iou: 0.9371 - val_dice_coef: 0.8710 - val_precision: 0.9548 - val_recall: 0.8253 - val_accuracy: 0.9278
# Epoch 88/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0669 - iou: 0.9331 - dice_coef: 0.8509 - precision: 0.9179 - recall: 0.8445 - accuracy: 0.9274 - val_loss: 0.0728 - val_iou: 0.9272 - val_dice_coef: 0.8598 - val_precision: 0.8969 - val_recall: 0.8723 - val_accuracy: 0.9228
# Epoch 89/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0612 - iou: 0.9388 - dice_coef: 0.8612 - precision: 0.9284 - recall: 0.8672 - accuracy: 0.9381 - val_loss: 0.0778 - val_iou: 0.9222 - val_dice_coef: 0.8642 - val_precision: 0.8700 - val_recall: 0.8880 - val_accuracy: 0.9157
# Epoch 90/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0629 - iou: 0.9371 - dice_coef: 0.8600 - precision: 0.9067 - recall: 0.8877 - accuracy: 0.9350 - val_loss: 0.0609 - val_iou: 0.9391 - val_dice_coef: 0.8877 - val_precision: 0.9396 - val_recall: 0.8701 - val_accuracy: 0.9355
# Epoch 91/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0623 - iou: 0.9377 - dice_coef: 0.8607 - precision: 0.9145 - recall: 0.8852 - accuracy: 0.9373 - val_loss: 0.0648 - val_iou: 0.9352 - val_dice_coef: 0.8753 - val_precision: 0.9660 - val_recall: 0.8159 - val_accuracy: 0.9257
# Epoch 92/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0598 - iou: 0.9402 - dice_coef: 0.8640 - precision: 0.9266 - recall: 0.8693 - accuracy: 0.9369 - val_loss: 0.0718 - val_iou: 0.9282 - val_dice_coef: 0.8785 - val_precision: 0.9223 - val_recall: 0.8597 - val_accuracy: 0.9251
# Epoch 93/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0564 - iou: 0.9436 - dice_coef: 0.8697 - precision: 0.9379 - recall: 0.8715 - accuracy: 0.9410 - val_loss: 0.0906 - val_iou: 0.9094 - val_dice_coef: 0.8511 - val_precision: 0.8610 - val_recall: 0.8644 - val_accuracy: 0.9036
# Epoch 94/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0579 - iou: 0.9421 - dice_coef: 0.8736 - precision: 0.9215 - recall: 0.8842 - accuracy: 0.9392 - val_loss: 0.0797 - val_iou: 0.9203 - val_dice_coef: 0.8701 - val_precision: 0.8641 - val_recall: 0.8923 - val_accuracy: 0.9127
# Epoch 95/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0629 - iou: 0.9371 - dice_coef: 0.8664 - precision: 0.9357 - recall: 0.8555 - accuracy: 0.9339 - val_loss: 0.0692 - val_iou: 0.9308 - val_dice_coef: 0.8812 - val_precision: 0.8839 - val_recall: 0.8948 - val_accuracy: 0.9238
# Epoch 96/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0623 - iou: 0.9377 - dice_coef: 0.8632 - precision: 0.9085 - recall: 0.8862 - accuracy: 0.9352 - val_loss: 0.0682 - val_iou: 0.9318 - val_dice_coef: 0.8757 - val_precision: 0.9294 - val_recall: 0.8554 - val_accuracy: 0.9264
# Epoch 97/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0673 - iou: 0.9327 - dice_coef: 0.8584 - precision: 0.9327 - recall: 0.8492 - accuracy: 0.9296 - val_loss: 0.0971 - val_iou: 0.9029 - val_dice_coef: 0.8391 - val_precision: 0.8182 - val_recall: 0.8873 - val_accuracy: 0.8921
# Epoch 98/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0635 - iou: 0.9365 - dice_coef: 0.8597 - precision: 0.9352 - recall: 0.8482 - accuracy: 0.9314 - val_loss: 0.0660 - val_iou: 0.9340 - val_dice_coef: 0.8661 - val_precision: 0.9321 - val_recall: 0.8546 - val_accuracy: 0.9275
# Epoch 99/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0644 - iou: 0.9356 - dice_coef: 0.8531 - precision: 0.9117 - recall: 0.8746 - accuracy: 0.9335 - val_loss: 0.0904 - val_iou: 0.9096 - val_dice_coef: 0.8187 - val_precision: 0.9067 - val_recall: 0.7916 - val_accuracy: 0.8994
# Epoch 100/100
# 121/121 [==============================] - 2s 15ms/step - loss: 0.0599 - iou: 0.9401 - dice_coef: 0.8656 - precision: 0.9250 - recall: 0.8730 - accuracy: 0.9385 - val_loss: 0.0893 - val_iou: 0.9107 - val_dice_coef: 0.8257 - val_precision: 0.9329 - val_recall: 0.7851 - val_accuracy: 0.9032

# %%
def segnet(epochs_num,savename):

    # Encoding layer
    img_input = Input(shape= (192, 256, 3))
    x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
    x = BatchNormalization(name='bn1')(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
    x = BatchNormalization(name='bn3')(x)
    x = Activation('relu')(x)
    x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
    x = BatchNormalization(name='bn4')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
    x = BatchNormalization(name='bn5')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
    x = BatchNormalization(name='bn6')(x)
    x = Activation('relu')(x)
    x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
    x = BatchNormalization(name='bn7')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
    x = BatchNormalization(name='bn8')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
    x = BatchNormalization(name='bn9')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
    x = BatchNormalization(name='bn10')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
    x = BatchNormalization(name='bn11')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
    x = BatchNormalization(name='bn12')(x)
    x = Activation('relu')(x)
    x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
    x = BatchNormalization(name='bn13')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)

    x = Dense(1024, activation = 'relu', name='fc1')(x)
    x = Dense(1024, activation = 'relu', name='fc2')(x)
    # Decoding Layer 
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
    x = BatchNormalization(name='bn14')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
    x = BatchNormalization(name='bn15')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
    x = BatchNormalization(name='bn16')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
    x = BatchNormalization(name='bn17')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
    x = BatchNormalization(name='bn18')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
    x = BatchNormalization(name='bn19')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
    x = BatchNormalization(name='bn20')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
    x = BatchNormalization(name='bn21')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
    x = BatchNormalization(name='bn22')(x)
    x = Activation('relu')(x)

    x = UpSampling2D()(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
    x = BatchNormalization(name='bn23')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
    x = BatchNormalization(name='bn24')(x)
    x = Activation('relu')(x)
    
    x = UpSampling2D()(x)
    x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv12')(x)
    x = BatchNormalization(name='bn25')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv13')(x)
    x = BatchNormalization(name='bn26')(x)
    x = Activation('sigmoid')(x)
    pred = Reshape((192,256))(x)
    
    model = Model(inputs=img_input, outputs=pred)
    
    model.compile(optimizer= SGD(lr=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
                  , metrics=[iou, dice_coef, precision, recall, accuracy])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18, validation_data= (x_val, y_val), verbose=1)
    
    model.save(savename)
    return model,hist

# %%
model_2, hist_2 = segnet(100, 'segnet_100_epoch.h5')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 192, 256, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 192, 256, 64)      1792
# _________________________________________________________________
# bn1 (BatchNormalization)     (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_24 (Activation)   (None, 192, 256, 64)      0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 192, 256, 64)      36928
# _________________________________________________________________
# bn2 (BatchNormalization)     (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_25 (Activation)   (None, 192, 256, 64)      0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 96, 128, 64)       0
# _________________________________________________________________
# conv3 (Conv2D)               (None, 96, 128, 128)      73856
# _________________________________________________________________
# bn3 (BatchNormalization)     (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_26 (Activation)   (None, 96, 128, 128)      0
# _________________________________________________________________
# conv4 (Conv2D)               (None, 96, 128, 128)      147584
# _________________________________________________________________
# bn4 (BatchNormalization)     (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_27 (Activation)   (None, 96, 128, 128)      0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 48, 64, 128)       0
# _________________________________________________________________
# conv5 (Conv2D)               (None, 48, 64, 256)       295168
# _________________________________________________________________
# bn5 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_28 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# conv6 (Conv2D)               (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn6 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_29 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# conv7 (Conv2D)               (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn7 (BatchNormalization)     (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_30 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 24, 32, 256)       0
# _________________________________________________________________
# conv8 (Conv2D)               (None, 24, 32, 512)       1180160
# _________________________________________________________________
# bn8 (BatchNormalization)     (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_31 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# conv9 (Conv2D)               (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn9 (BatchNormalization)     (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_32 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# conv10 (Conv2D)              (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn10 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_33 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 12, 16, 512)       0
# _________________________________________________________________
# conv11 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn11 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_34 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# conv12 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn12 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_35 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# conv13 (Conv2D)              (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn13 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_36 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 6, 8, 512)         0
# _________________________________________________________________
# fc1 (Dense)                  (None, 6, 8, 1024)        525312
# _________________________________________________________________
# fc2 (Dense)                  (None, 6, 8, 1024)        1049600
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 12, 16, 1024)      0
# _________________________________________________________________
# deconv1 (Conv2DTranspose)    (None, 12, 16, 512)       4719104
# _________________________________________________________________
# bn14 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_37 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# deconv2 (Conv2DTranspose)    (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn15 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_38 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# deconv3 (Conv2DTranspose)    (None, 12, 16, 512)       2359808
# _________________________________________________________________
# bn16 (BatchNormalization)    (None, 12, 16, 512)       2048
# _________________________________________________________________
# activation_39 (Activation)   (None, 12, 16, 512)       0
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv4 (Conv2DTranspose)    (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn17 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_40 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv5 (Conv2DTranspose)    (None, 24, 32, 512)       2359808
# _________________________________________________________________
# bn18 (BatchNormalization)    (None, 24, 32, 512)       2048
# _________________________________________________________________
# activation_41 (Activation)   (None, 24, 32, 512)       0
# _________________________________________________________________
# deconv6 (Conv2DTranspose)    (None, 24, 32, 256)       1179904
# _________________________________________________________________
# bn19 (BatchNormalization)    (None, 24, 32, 256)       1024
# _________________________________________________________________
# activation_42 (Activation)   (None, 24, 32, 256)       0
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv7 (Conv2DTranspose)    (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn20 (BatchNormalization)    (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_43 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv8 (Conv2DTranspose)    (None, 48, 64, 256)       590080
# _________________________________________________________________
# bn21 (BatchNormalization)    (None, 48, 64, 256)       1024
# _________________________________________________________________
# activation_44 (Activation)   (None, 48, 64, 256)       0
# _________________________________________________________________
# deconv9 (Conv2DTranspose)    (None, 48, 64, 128)       295040
# _________________________________________________________________
# bn22 (BatchNormalization)    (None, 48, 64, 128)       512
# _________________________________________________________________
# activation_45 (Activation)   (None, 48, 64, 128)       0
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 96, 128, 128)      0
# _________________________________________________________________
# deconv10 (Conv2DTranspose)   (None, 96, 128, 128)      147584
# _________________________________________________________________
# bn23 (BatchNormalization)    (None, 96, 128, 128)      512
# _________________________________________________________________
# activation_46 (Activation)   (None, 96, 128, 128)      0
# _________________________________________________________________
# deconv11 (Conv2DTranspose)   (None, 96, 128, 64)       73792
# _________________________________________________________________
# bn24 (BatchNormalization)    (None, 96, 128, 64)       256
# _________________________________________________________________
# activation_47 (Activation)   (None, 96, 128, 64)       0
# _________________________________________________________________
# up_sampling2d_10 (UpSampling (None, 192, 256, 64)      0
# _________________________________________________________________
# deconv12 (Conv2DTranspose)   (None, 192, 256, 64)      36928
# _________________________________________________________________
# bn25 (BatchNormalization)    (None, 192, 256, 64)      256
# _________________________________________________________________
# activation_48 (Activation)   (None, 192, 256, 64)      0
# _________________________________________________________________
# deconv13 (Conv2DTranspose)   (None, 192, 256, 1)       577
# _________________________________________________________________
# bn26 (BatchNormalization)    (None, 192, 256, 1)       4
# _________________________________________________________________
# activation_49 (Activation)   (None, 192, 256, 1)       0
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 192, 256)          0
# =================================================================
# Total params: 33,393,669
# Trainable params: 33,377,795
# Non-trainable params: 15,874
# _________________________________________________________________
# Train on 121 samples, validate on 31 samples
# Epoch 1/100
# 121/121 [==============================] - 11s 91ms/step - loss: 0.7627 - iou: 0.6579 - dice_coef: 0.3909 - precision: 0.3068 - recall: 0.6476 - accuracy: 0.4332 - val_loss: 0.7831 - val_iou: 0.6587 - val_dice_coef: 0.4194 - val_precision: 0.3460 - val_recall: 0.6700 - val_accuracy: 0.4191
# Epoch 2/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.7361 - iou: 0.6689 - dice_coef: 0.3996 - precision: 0.3340 - recall: 0.6917 - accuracy: 0.4722 - val_loss: 0.7889 - val_iou: 0.6607 - val_dice_coef: 0.4385 - val_precision: 0.3610 - val_recall: 0.7859 - val_accuracy: 0.4186
# Epoch 3/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.6928 - iou: 0.6859 - dice_coef: 0.4180 - precision: 0.3886 - recall: 0.6902 - accuracy: 0.5659 - val_loss: 0.8273 - val_iou: 0.6573 - val_dice_coef: 0.4600 - val_precision: 0.3698 - val_recall: 0.8659 - val_accuracy: 0.4176
# Epoch 4/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.6717 - iou: 0.7021 - dice_coef: 0.4318 - precision: 0.4605 - recall: 0.6539 - accuracy: 0.6526 - val_loss: 0.9414 - val_iou: 0.6457 - val_dice_coef: 0.5042 - val_precision: 0.3728 - val_recall: 0.9366 - val_accuracy: 0.4072
# Epoch 5/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.5770 - iou: 0.7409 - dice_coef: 0.4788 - precision: 0.5987 - recall: 0.7344 - accuracy: 0.7632 - val_loss: 0.7925 - val_iou: 0.6689 - val_dice_coef: 0.4755 - val_precision: 0.3911 - val_recall: 0.8270 - val_accuracy: 0.4718
# Epoch 6/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.5124 - iou: 0.7689 - dice_coef: 0.5189 - precision: 0.6750 - recall: 0.7828 - accuracy: 0.8128 - val_loss: 0.7319 - val_iou: 0.6904 - val_dice_coef: 0.4738 - val_precision: 0.4236 - val_recall: 0.7512 - val_accuracy: 0.5441
# Epoch 7/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.4902 - iou: 0.7818 - dice_coef: 0.5303 - precision: 0.7249 - recall: 0.7779 - accuracy: 0.8377 - val_loss: 0.7109 - val_iou: 0.6951 - val_dice_coef: 0.5054 - val_precision: 0.4289 - val_recall: 0.8328 - val_accuracy: 0.5395
# Epoch 8/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.4735 - iou: 0.7915 - dice_coef: 0.5427 - precision: 0.7419 - recall: 0.7914 - accuracy: 0.8485 - val_loss: 0.7160 - val_iou: 0.6963 - val_dice_coef: 0.5338 - val_precision: 0.4286 - val_recall: 0.9117 - val_accuracy: 0.5314
# Epoch 9/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.4613 - iou: 0.7988 - dice_coef: 0.5497 - precision: 0.7484 - recall: 0.8137 - accuracy: 0.8546 - val_loss: 0.6464 - val_iou: 0.7199 - val_dice_coef: 0.5510 - val_precision: 0.4704 - val_recall: 0.9193 - val_accuracy: 0.5997
# Epoch 10/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.4386 - iou: 0.8100 - dice_coef: 0.5657 - precision: 0.7785 - recall: 0.8371 - accuracy: 0.8741 - val_loss: 0.5674 - val_iou: 0.7512 - val_dice_coef: 0.5666 - val_precision: 0.5547 - val_recall: 0.8838 - val_accuracy: 0.7069
# Epoch 11/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.4360 - iou: 0.8126 - dice_coef: 0.5672 - precision: 0.7822 - recall: 0.8502 - accuracy: 0.8777 - val_loss: 0.5145 - val_iou: 0.7774 - val_dice_coef: 0.5861 - val_precision: 0.6449 - val_recall: 0.8547 - val_accuracy: 0.7816
# Epoch 12/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.4177 - iou: 0.8217 - dice_coef: 0.5782 - precision: 0.8032 - recall: 0.8725 - accuracy: 0.8923 - val_loss: 0.4881 - val_iou: 0.7926 - val_dice_coef: 0.6095 - val_precision: 0.6785 - val_recall: 0.8666 - val_accuracy: 0.8087
# Epoch 13/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.4174 - iou: 0.8215 - dice_coef: 0.5772 - precision: 0.8068 - recall: 0.8594 - accuracy: 0.8909 - val_loss: 0.4547 - val_iou: 0.8078 - val_dice_coef: 0.6202 - val_precision: 0.7296 - val_recall: 0.8522 - val_accuracy: 0.8369
# Epoch 14/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.4145 - iou: 0.8246 - dice_coef: 0.5767 - precision: 0.8178 - recall: 0.8623 - accuracy: 0.8953 - val_loss: 0.4412 - val_iou: 0.8152 - val_dice_coef: 0.6247 - val_precision: 0.7567 - val_recall: 0.8443 - val_accuracy: 0.8489
# Epoch 15/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.4084 - iou: 0.8274 - dice_coef: 0.5829 - precision: 0.8172 - recall: 0.8686 - accuracy: 0.8953 - val_loss: 0.4439 - val_iou: 0.8137 - val_dice_coef: 0.6184 - val_precision: 0.7520 - val_recall: 0.8274 - val_accuracy: 0.8419
# Epoch 16/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.4079 - iou: 0.8285 - dice_coef: 0.5842 - precision: 0.8145 - recall: 0.8558 - accuracy: 0.8934 - val_loss: 0.4292 - val_iou: 0.8209 - val_dice_coef: 0.6203 - val_precision: 0.7740 - val_recall: 0.8240 - val_accuracy: 0.8519
# Epoch 17/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3877 - iou: 0.8384 - dice_coef: 0.5969 - precision: 0.8441 - recall: 0.8848 - accuracy: 0.9112 - val_loss: 0.4410 - val_iou: 0.8152 - val_dice_coef: 0.6224 - val_precision: 0.7380 - val_recall: 0.8498 - val_accuracy: 0.8395
# Epoch 18/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3865 - iou: 0.8396 - dice_coef: 0.5973 - precision: 0.8388 - recall: 0.8900 - accuracy: 0.9101 - val_loss: 0.4343 - val_iou: 0.8190 - val_dice_coef: 0.6128 - val_precision: 0.7705 - val_recall: 0.8169 - val_accuracy: 0.8497
# Epoch 19/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3693 - iou: 0.8486 - dice_coef: 0.6107 - precision: 0.8631 - recall: 0.9043 - accuracy: 0.9249 - val_loss: 0.4347 - val_iou: 0.8207 - val_dice_coef: 0.6050 - val_precision: 0.7946 - val_recall: 0.7823 - val_accuracy: 0.8530
# Epoch 20/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3761 - iou: 0.8452 - dice_coef: 0.6041 - precision: 0.8549 - recall: 0.8902 - accuracy: 0.9177 - val_loss: 0.4180 - val_iou: 0.8290 - val_dice_coef: 0.6274 - val_precision: 0.7838 - val_recall: 0.8325 - val_accuracy: 0.8616
# Epoch 21/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3621 - iou: 0.8528 - dice_coef: 0.6148 - precision: 0.8744 - recall: 0.9047 - accuracy: 0.9292 - val_loss: 0.4160 - val_iou: 0.8301 - val_dice_coef: 0.6408 - val_precision: 0.7553 - val_recall: 0.8590 - val_accuracy: 0.8550
# Epoch 22/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3639 - iou: 0.8517 - dice_coef: 0.6125 - precision: 0.8665 - recall: 0.8970 - accuracy: 0.9232 - val_loss: 0.4086 - val_iou: 0.8338 - val_dice_coef: 0.6561 - val_precision: 0.7505 - val_recall: 0.8943 - val_accuracy: 0.8602
# Epoch 23/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3497 - iou: 0.8593 - dice_coef: 0.6232 - precision: 0.8871 - recall: 0.9112 - accuracy: 0.9354 - val_loss: 0.3905 - val_iou: 0.8423 - val_dice_coef: 0.6602 - val_precision: 0.7768 - val_recall: 0.8920 - val_accuracy: 0.8740
# Epoch 24/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3519 - iou: 0.8583 - dice_coef: 0.6210 - precision: 0.8768 - recall: 0.9086 - accuracy: 0.9305 - val_loss: 0.3678 - val_iou: 0.8536 - val_dice_coef: 0.6670 - val_precision: 0.8147 - val_recall: 0.8821 - val_accuracy: 0.8889
# Epoch 25/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3524 - iou: 0.8586 - dice_coef: 0.6210 - precision: 0.8655 - recall: 0.9076 - accuracy: 0.9259 - val_loss: 0.4013 - val_iou: 0.8359 - val_dice_coef: 0.6603 - val_precision: 0.7505 - val_recall: 0.9078 - val_accuracy: 0.8626
# Epoch 26/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3471 - iou: 0.8616 - dice_coef: 0.6240 - precision: 0.8812 - recall: 0.9032 - accuracy: 0.9300 - val_loss: 0.4107 - val_iou: 0.8322 - val_dice_coef: 0.6655 - val_precision: 0.7355 - val_recall: 0.9233 - val_accuracy: 0.8563
# Epoch 27/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3456 - iou: 0.8619 - dice_coef: 0.6256 - precision: 0.8866 - recall: 0.9004 - accuracy: 0.9306 - val_loss: 0.3631 - val_iou: 0.8569 - val_dice_coef: 0.6740 - val_precision: 0.8161 - val_recall: 0.8910 - val_accuracy: 0.8912
# Epoch 28/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3391 - iou: 0.8656 - dice_coef: 0.6284 - precision: 0.8815 - recall: 0.9094 - accuracy: 0.9329 - val_loss: 0.3456 - val_iou: 0.8657 - val_dice_coef: 0.6728 - val_precision: 0.8567 - val_recall: 0.8690 - val_accuracy: 0.9033
# Epoch 29/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3449 - iou: 0.8622 - dice_coef: 0.6252 - precision: 0.8745 - recall: 0.8934 - accuracy: 0.9258 - val_loss: 0.3337 - val_iou: 0.8712 - val_dice_coef: 0.6869 - val_precision: 0.8512 - val_recall: 0.9040 - val_accuracy: 0.9104
# Epoch 30/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3275 - iou: 0.8721 - dice_coef: 0.6397 - precision: 0.8910 - recall: 0.9204 - accuracy: 0.9388 - val_loss: 0.3272 - val_iou: 0.8754 - val_dice_coef: 0.6812 - val_precision: 0.8741 - val_recall: 0.8889 - val_accuracy: 0.9159
# Epoch 31/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3287 - iou: 0.8717 - dice_coef: 0.6373 - precision: 0.8794 - recall: 0.9183 - accuracy: 0.9343 - val_loss: 0.3512 - val_iou: 0.8621 - val_dice_coef: 0.6811 - val_precision: 0.8141 - val_recall: 0.9154 - val_accuracy: 0.8964
# Epoch 32/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3397 - iou: 0.8662 - dice_coef: 0.6272 - precision: 0.8639 - recall: 0.9071 - accuracy: 0.9231 - val_loss: 0.3849 - val_iou: 0.8452 - val_dice_coef: 0.6777 - val_precision: 0.7495 - val_recall: 0.9356 - val_accuracy: 0.8687
# Epoch 33/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3227 - iou: 0.8748 - dice_coef: 0.6414 - precision: 0.8936 - recall: 0.9135 - accuracy: 0.9385 - val_loss: 0.3842 - val_iou: 0.8472 - val_dice_coef: 0.6830 - val_precision: 0.7527 - val_recall: 0.9396 - val_accuracy: 0.8712
# Epoch 34/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3088 - iou: 0.8818 - dice_coef: 0.6530 - precision: 0.9227 - recall: 0.9190 - accuracy: 0.9503 - val_loss: 0.3680 - val_iou: 0.8546 - val_dice_coef: 0.6883 - val_precision: 0.7695 - val_recall: 0.9396 - val_accuracy: 0.8802
# Epoch 35/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3127 - iou: 0.8797 - dice_coef: 0.6494 - precision: 0.9001 - recall: 0.9246 - accuracy: 0.9428 - val_loss: 0.3491 - val_iou: 0.8633 - val_dice_coef: 0.6852 - val_precision: 0.7975 - val_recall: 0.9261 - val_accuracy: 0.8920
# Epoch 36/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3175 - iou: 0.8779 - dice_coef: 0.6444 - precision: 0.8908 - recall: 0.9144 - accuracy: 0.9371 - val_loss: 0.3747 - val_iou: 0.8500 - val_dice_coef: 0.6829 - val_precision: 0.7552 - val_recall: 0.9453 - val_accuracy: 0.8732
# Epoch 37/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3003 - iou: 0.8866 - dice_coef: 0.6601 - precision: 0.9212 - recall: 0.9272 - accuracy: 0.9519 - val_loss: 0.4243 - val_iou: 0.8294 - val_dice_coef: 0.6745 - val_precision: 0.6972 - val_recall: 0.9634 - val_accuracy: 0.8404
# Epoch 38/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3032 - iou: 0.8851 - dice_coef: 0.6578 - precision: 0.9100 - recall: 0.9251 - accuracy: 0.9462 - val_loss: 0.3755 - val_iou: 0.8501 - val_dice_coef: 0.6856 - val_precision: 0.7510 - val_recall: 0.9503 - val_accuracy: 0.8723
# Epoch 39/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2988 - iou: 0.8876 - dice_coef: 0.6606 - precision: 0.9127 - recall: 0.9279 - accuracy: 0.9487 - val_loss: 0.3299 - val_iou: 0.8726 - val_dice_coef: 0.6986 - val_precision: 0.8178 - val_recall: 0.9334 - val_accuracy: 0.9042
# Epoch 40/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2925 - iou: 0.8915 - dice_coef: 0.6668 - precision: 0.9172 - recall: 0.9315 - accuracy: 0.9515 - val_loss: 0.3199 - val_iou: 0.8781 - val_dice_coef: 0.6994 - val_precision: 0.8371 - val_recall: 0.9223 - val_accuracy: 0.9095
# Epoch 41/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2863 - iou: 0.8945 - dice_coef: 0.6718 - precision: 0.9282 - recall: 0.9327 - accuracy: 0.9563 - val_loss: 0.3255 - val_iou: 0.8753 - val_dice_coef: 0.7032 - val_precision: 0.8186 - val_recall: 0.9374 - val_accuracy: 0.9044
# Epoch 42/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2889 - iou: 0.8933 - dice_coef: 0.6690 - precision: 0.9143 - recall: 0.9343 - accuracy: 0.9515 - val_loss: 0.3280 - val_iou: 0.8750 - val_dice_coef: 0.7003 - val_precision: 0.8147 - val_recall: 0.9404 - val_accuracy: 0.9040
# Epoch 43/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.3025 - iou: 0.8859 - dice_coef: 0.6592 - precision: 0.8943 - recall: 0.9232 - accuracy: 0.9378 - val_loss: 0.3384 - val_iou: 0.8701 - val_dice_coef: 0.6933 - val_precision: 0.8027 - val_recall: 0.9254 - val_accuracy: 0.8949
# Epoch 44/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2818 - iou: 0.8968 - dice_coef: 0.6750 - precision: 0.9220 - recall: 0.9379 - accuracy: 0.9551 - val_loss: 0.3438 - val_iou: 0.8678 - val_dice_coef: 0.6910 - val_precision: 0.7959 - val_recall: 0.9165 - val_accuracy: 0.8893
# Epoch 45/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2852 - iou: 0.8948 - dice_coef: 0.6720 - precision: 0.9161 - recall: 0.9295 - accuracy: 0.9500 - val_loss: 0.3468 - val_iou: 0.8661 - val_dice_coef: 0.6856 - val_precision: 0.7983 - val_recall: 0.9006 - val_accuracy: 0.8869
# Epoch 46/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2864 - iou: 0.8945 - dice_coef: 0.6718 - precision: 0.9097 - recall: 0.9243 - accuracy: 0.9463 - val_loss: 0.3375 - val_iou: 0.8709 - val_dice_coef: 0.6890 - val_precision: 0.8167 - val_recall: 0.8997 - val_accuracy: 0.8948
# Epoch 47/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2707 - iou: 0.9026 - dice_coef: 0.6844 - precision: 0.9368 - recall: 0.9365 - accuracy: 0.9602 - val_loss: 0.3283 - val_iou: 0.8743 - val_dice_coef: 0.6995 - val_precision: 0.8187 - val_recall: 0.9168 - val_accuracy: 0.8992
# Epoch 48/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2737 - iou: 0.9005 - dice_coef: 0.6814 - precision: 0.9303 - recall: 0.9311 - accuracy: 0.9557 - val_loss: 0.3228 - val_iou: 0.8778 - val_dice_coef: 0.7040 - val_precision: 0.8200 - val_recall: 0.9284 - val_accuracy: 0.9028
# Epoch 49/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2737 - iou: 0.9015 - dice_coef: 0.6818 - precision: 0.9147 - recall: 0.9386 - accuracy: 0.9536 - val_loss: 0.3178 - val_iou: 0.8804 - val_dice_coef: 0.7043 - val_precision: 0.8277 - val_recall: 0.9310 - val_accuracy: 0.9076
# Epoch 50/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2640 - iou: 0.9063 - dice_coef: 0.6906 - precision: 0.9306 - recall: 0.9456 - accuracy: 0.9606 - val_loss: 0.3392 - val_iou: 0.8697 - val_dice_coef: 0.6993 - val_precision: 0.7966 - val_recall: 0.9331 - val_accuracy: 0.8916
# Epoch 51/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2697 - iou: 0.9030 - dice_coef: 0.6860 - precision: 0.9216 - recall: 0.9330 - accuracy: 0.9535 - val_loss: 0.3224 - val_iou: 0.8789 - val_dice_coef: 0.6993 - val_precision: 0.8279 - val_recall: 0.9194 - val_accuracy: 0.9040
# Epoch 52/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2635 - iou: 0.9067 - dice_coef: 0.6914 - precision: 0.9237 - recall: 0.9437 - accuracy: 0.9575 - val_loss: 0.3166 - val_iou: 0.8819 - val_dice_coef: 0.7020 - val_precision: 0.8347 - val_recall: 0.9119 - val_accuracy: 0.9047
# Epoch 53/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2650 - iou: 0.9055 - dice_coef: 0.6890 - precision: 0.9195 - recall: 0.9400 - accuracy: 0.9558 - val_loss: 0.3211 - val_iou: 0.8783 - val_dice_coef: 0.7122 - val_precision: 0.8102 - val_recall: 0.9364 - val_accuracy: 0.8999
# Epoch 54/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2645 - iou: 0.9058 - dice_coef: 0.6888 - precision: 0.9219 - recall: 0.9368 - accuracy: 0.9556 - val_loss: 0.2865 - val_iou: 0.8976 - val_dice_coef: 0.7184 - val_precision: 0.8768 - val_recall: 0.9099 - val_accuracy: 0.9227
# Epoch 55/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2573 - iou: 0.9096 - dice_coef: 0.6951 - precision: 0.9286 - recall: 0.9445 - accuracy: 0.9599 - val_loss: 0.2929 - val_iou: 0.8961 - val_dice_coef: 0.7057 - val_precision: 0.8941 - val_recall: 0.8611 - val_accuracy: 0.9158
# Epoch 56/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2634 - iou: 0.9063 - dice_coef: 0.6916 - precision: 0.9222 - recall: 0.9341 - accuracy: 0.9531 - val_loss: 0.2878 - val_iou: 0.8985 - val_dice_coef: 0.7054 - val_precision: 0.9138 - val_recall: 0.8468 - val_accuracy: 0.9183
# Epoch 57/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2564 - iou: 0.9102 - dice_coef: 0.6974 - precision: 0.9307 - recall: 0.9363 - accuracy: 0.9576 - val_loss: 0.2923 - val_iou: 0.8974 - val_dice_coef: 0.6943 - val_precision: 0.9313 - val_recall: 0.8228 - val_accuracy: 0.9162
# Epoch 58/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2456 - iou: 0.9161 - dice_coef: 0.7072 - precision: 0.9362 - recall: 0.9515 - accuracy: 0.9644 - val_loss: 0.2951 - val_iou: 0.8969 - val_dice_coef: 0.6915 - val_precision: 0.9299 - val_recall: 0.8217 - val_accuracy: 0.9144
# Epoch 59/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2489 - iou: 0.9140 - dice_coef: 0.7032 - precision: 0.9272 - recall: 0.9478 - accuracy: 0.9607 - val_loss: 0.2950 - val_iou: 0.8975 - val_dice_coef: 0.6948 - val_precision: 0.9320 - val_recall: 0.8166 - val_accuracy: 0.9122
# Epoch 60/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2456 - iou: 0.9165 - dice_coef: 0.7076 - precision: 0.9328 - recall: 0.9476 - accuracy: 0.9616 - val_loss: 0.2851 - val_iou: 0.9004 - val_dice_coef: 0.7120 - val_precision: 0.9072 - val_recall: 0.8725 - val_accuracy: 0.9200
# Epoch 61/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2466 - iou: 0.9152 - dice_coef: 0.7067 - precision: 0.9316 - recall: 0.9440 - accuracy: 0.9605 - val_loss: 0.2824 - val_iou: 0.9009 - val_dice_coef: 0.7183 - val_precision: 0.8959 - val_recall: 0.8900 - val_accuracy: 0.9217
# Epoch 62/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2457 - iou: 0.9156 - dice_coef: 0.7077 - precision: 0.9310 - recall: 0.9464 - accuracy: 0.9601 - val_loss: 0.2832 - val_iou: 0.9003 - val_dice_coef: 0.7201 - val_precision: 0.8828 - val_recall: 0.9028 - val_accuracy: 0.9213
# Epoch 63/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2392 - iou: 0.9191 - dice_coef: 0.7131 - precision: 0.9381 - recall: 0.9496 - accuracy: 0.9646 - val_loss: 0.2900 - val_iou: 0.8956 - val_dice_coef: 0.7215 - val_precision: 0.8577 - val_recall: 0.9176 - val_accuracy: 0.9159
# Epoch 64/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2432 - iou: 0.9167 - dice_coef: 0.7103 - precision: 0.9344 - recall: 0.9413 - accuracy: 0.9597 - val_loss: 0.2921 - val_iou: 0.8958 - val_dice_coef: 0.7143 - val_precision: 0.8704 - val_recall: 0.8863 - val_accuracy: 0.9124
# Epoch 65/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2352 - iou: 0.9216 - dice_coef: 0.7173 - precision: 0.9402 - recall: 0.9496 - accuracy: 0.9645 - val_loss: 0.2829 - val_iou: 0.9002 - val_dice_coef: 0.7201 - val_precision: 0.8807 - val_recall: 0.8936 - val_accuracy: 0.9184
# Epoch 66/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2440 - iou: 0.9164 - dice_coef: 0.7097 - precision: 0.9226 - recall: 0.9411 - accuracy: 0.9568 - val_loss: 0.2841 - val_iou: 0.9012 - val_dice_coef: 0.7156 - val_precision: 0.8978 - val_recall: 0.8767 - val_accuracy: 0.9180
# Epoch 67/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2376 - iou: 0.9194 - dice_coef: 0.7155 - precision: 0.9340 - recall: 0.9418 - accuracy: 0.9611 - val_loss: 0.2838 - val_iou: 0.9012 - val_dice_coef: 0.7130 - val_precision: 0.9074 - val_recall: 0.8646 - val_accuracy: 0.9185
# Epoch 68/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2333 - iou: 0.9214 - dice_coef: 0.7182 - precision: 0.9400 - recall: 0.9452 - accuracy: 0.9635 - val_loss: 0.2795 - val_iou: 0.9038 - val_dice_coef: 0.7132 - val_precision: 0.9195 - val_recall: 0.8552 - val_accuracy: 0.9196
# Epoch 69/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2277 - iou: 0.9249 - dice_coef: 0.7246 - precision: 0.9405 - recall: 0.9538 - accuracy: 0.9666 - val_loss: 0.2807 - val_iou: 0.9035 - val_dice_coef: 0.7144 - val_precision: 0.9147 - val_recall: 0.8578 - val_accuracy: 0.9187
# Epoch 70/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2405 - iou: 0.9181 - dice_coef: 0.7124 - precision: 0.9279 - recall: 0.9402 - accuracy: 0.9580 - val_loss: 0.2760 - val_iou: 0.9032 - val_dice_coef: 0.7285 - val_precision: 0.8869 - val_recall: 0.8953 - val_accuracy: 0.9199
# Epoch 71/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2244 - iou: 0.9264 - dice_coef: 0.7273 - precision: 0.9465 - recall: 0.9516 - accuracy: 0.9675 - val_loss: 0.2801 - val_iou: 0.9018 - val_dice_coef: 0.7211 - val_precision: 0.8880 - val_recall: 0.8888 - val_accuracy: 0.9189
# Epoch 72/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2400 - iou: 0.9188 - dice_coef: 0.7148 - precision: 0.9199 - recall: 0.9426 - accuracy: 0.9546 - val_loss: 0.2782 - val_iou: 0.9027 - val_dice_coef: 0.7240 - val_precision: 0.8842 - val_recall: 0.9021 - val_accuracy: 0.9212
# Epoch 73/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2207 - iou: 0.9282 - dice_coef: 0.7311 - precision: 0.9466 - recall: 0.9539 - accuracy: 0.9684 - val_loss: 0.2788 - val_iou: 0.9027 - val_dice_coef: 0.7244 - val_precision: 0.8862 - val_recall: 0.8940 - val_accuracy: 0.9193
# Epoch 74/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2249 - iou: 0.9259 - dice_coef: 0.7275 - precision: 0.9359 - recall: 0.9528 - accuracy: 0.9642 - val_loss: 0.2828 - val_iou: 0.9033 - val_dice_coef: 0.7139 - val_precision: 0.9084 - val_recall: 0.8484 - val_accuracy: 0.9142
# Epoch 75/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2211 - iou: 0.9280 - dice_coef: 0.7308 - precision: 0.9399 - recall: 0.9538 - accuracy: 0.9663 - val_loss: 0.2796 - val_iou: 0.9044 - val_dice_coef: 0.7178 - val_precision: 0.9058 - val_recall: 0.8515 - val_accuracy: 0.9148
# Epoch 76/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2219 - iou: 0.9274 - dice_coef: 0.7299 - precision: 0.9356 - recall: 0.9545 - accuracy: 0.9654 - val_loss: 0.2806 - val_iou: 0.9042 - val_dice_coef: 0.7152 - val_precision: 0.9094 - val_recall: 0.8443 - val_accuracy: 0.9136
# Epoch 77/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2278 - iou: 0.9236 - dice_coef: 0.7254 - precision: 0.9348 - recall: 0.9438 - accuracy: 0.9604 - val_loss: 0.2703 - val_iou: 0.9083 - val_dice_coef: 0.7228 - val_precision: 0.9172 - val_recall: 0.8623 - val_accuracy: 0.9221
# Epoch 78/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2231 - iou: 0.9266 - dice_coef: 0.7294 - precision: 0.9357 - recall: 0.9462 - accuracy: 0.9625 - val_loss: 0.2760 - val_iou: 0.9059 - val_dice_coef: 0.7154 - val_precision: 0.9193 - val_recall: 0.8431 - val_accuracy: 0.9172
# Epoch 79/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2229 - iou: 0.9262 - dice_coef: 0.7293 - precision: 0.9327 - recall: 0.9463 - accuracy: 0.9617 - val_loss: 0.2734 - val_iou: 0.9068 - val_dice_coef: 0.7213 - val_precision: 0.9228 - val_recall: 0.8463 - val_accuracy: 0.9181
# Epoch 80/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2171 - iou: 0.9295 - dice_coef: 0.7347 - precision: 0.9434 - recall: 0.9479 - accuracy: 0.9656 - val_loss: 0.2865 - val_iou: 0.9030 - val_dice_coef: 0.7065 - val_precision: 0.9374 - val_recall: 0.8023 - val_accuracy: 0.9090
# Epoch 81/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2101 - iou: 0.9335 - dice_coef: 0.7418 - precision: 0.9460 - recall: 0.9573 - accuracy: 0.9694 - val_loss: 0.2827 - val_iou: 0.9052 - val_dice_coef: 0.7068 - val_precision: 0.9427 - val_recall: 0.8077 - val_accuracy: 0.9120
# Epoch 82/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2193 - iou: 0.9284 - dice_coef: 0.7350 - precision: 0.9319 - recall: 0.9477 - accuracy: 0.9619 - val_loss: 0.2689 - val_iou: 0.9099 - val_dice_coef: 0.7236 - val_precision: 0.9247 - val_recall: 0.8489 - val_accuracy: 0.9204
# Epoch 83/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2157 - iou: 0.9303 - dice_coef: 0.7367 - precision: 0.9390 - recall: 0.9491 - accuracy: 0.9644 - val_loss: 0.2651 - val_iou: 0.9114 - val_dice_coef: 0.7269 - val_precision: 0.9240 - val_recall: 0.8606 - val_accuracy: 0.9248
# Epoch 84/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2152 - iou: 0.9302 - dice_coef: 0.7377 - precision: 0.9348 - recall: 0.9506 - accuracy: 0.9633 - val_loss: 0.2700 - val_iou: 0.9091 - val_dice_coef: 0.7257 - val_precision: 0.9144 - val_recall: 0.8606 - val_accuracy: 0.9207
# Epoch 85/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2123 - iou: 0.9316 - dice_coef: 0.7390 - precision: 0.9412 - recall: 0.9508 - accuracy: 0.9662 - val_loss: 0.2728 - val_iou: 0.9082 - val_dice_coef: 0.7227 - val_precision: 0.9186 - val_recall: 0.8482 - val_accuracy: 0.9176
# Epoch 86/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2062 - iou: 0.9350 - dice_coef: 0.7463 - precision: 0.9469 - recall: 0.9537 - accuracy: 0.9687 - val_loss: 0.2755 - val_iou: 0.9068 - val_dice_coef: 0.7208 - val_precision: 0.9207 - val_recall: 0.8348 - val_accuracy: 0.9143
# Epoch 87/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2067 - iou: 0.9346 - dice_coef: 0.7443 - precision: 0.9441 - recall: 0.9546 - accuracy: 0.9688 - val_loss: 0.2630 - val_iou: 0.9109 - val_dice_coef: 0.7368 - val_precision: 0.9040 - val_recall: 0.8782 - val_accuracy: 0.9219
# Epoch 88/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2051 - iou: 0.9354 - dice_coef: 0.7462 - precision: 0.9500 - recall: 0.9491 - accuracy: 0.9687 - val_loss: 0.2599 - val_iou: 0.9115 - val_dice_coef: 0.7419 - val_precision: 0.8984 - val_recall: 0.8902 - val_accuracy: 0.9230
# Epoch 89/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2121 - iou: 0.9314 - dice_coef: 0.7395 - precision: 0.9384 - recall: 0.9444 - accuracy: 0.9634 - val_loss: 0.2562 - val_iou: 0.9136 - val_dice_coef: 0.7435 - val_precision: 0.9052 - val_recall: 0.8883 - val_accuracy: 0.9257
# Epoch 90/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2087 - iou: 0.9333 - dice_coef: 0.7445 - precision: 0.9417 - recall: 0.9497 - accuracy: 0.9649 - val_loss: 0.2611 - val_iou: 0.9129 - val_dice_coef: 0.7341 - val_precision: 0.9182 - val_recall: 0.8703 - val_accuracy: 0.9250
# Epoch 91/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2114 - iou: 0.9319 - dice_coef: 0.7421 - precision: 0.9306 - recall: 0.9529 - accuracy: 0.9624 - val_loss: 0.2631 - val_iou: 0.9123 - val_dice_coef: 0.7319 - val_precision: 0.9190 - val_recall: 0.8656 - val_accuracy: 0.9236
# Epoch 92/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2062 - iou: 0.9343 - dice_coef: 0.7469 - precision: 0.9357 - recall: 0.9537 - accuracy: 0.9651 - val_loss: 0.2647 - val_iou: 0.9107 - val_dice_coef: 0.7354 - val_precision: 0.9061 - val_recall: 0.8715 - val_accuracy: 0.9200
# Epoch 93/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2146 - iou: 0.9303 - dice_coef: 0.7408 - precision: 0.9296 - recall: 0.9443 - accuracy: 0.9593 - val_loss: 0.2645 - val_iou: 0.9101 - val_dice_coef: 0.7351 - val_precision: 0.9040 - val_recall: 0.8718 - val_accuracy: 0.9197
# Epoch 94/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.1978 - iou: 0.9387 - dice_coef: 0.7540 - precision: 0.9473 - recall: 0.9563 - accuracy: 0.9698 - val_loss: 0.2649 - val_iou: 0.9098 - val_dice_coef: 0.7337 - val_precision: 0.9093 - val_recall: 0.8618 - val_accuracy: 0.9184
# Epoch 95/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.1938 - iou: 0.9408 - dice_coef: 0.7581 - precision: 0.9528 - recall: 0.9588 - accuracy: 0.9720 - val_loss: 0.2641 - val_iou: 0.9115 - val_dice_coef: 0.7333 - val_precision: 0.9217 - val_recall: 0.8534 - val_accuracy: 0.9201
# Epoch 96/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2053 - iou: 0.9348 - dice_coef: 0.7492 - precision: 0.9407 - recall: 0.9449 - accuracy: 0.9634 - val_loss: 0.2641 - val_iou: 0.9118 - val_dice_coef: 0.7339 - val_precision: 0.9213 - val_recall: 0.8490 - val_accuracy: 0.9190
# Epoch 97/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2128 - iou: 0.9307 - dice_coef: 0.7408 - precision: 0.9283 - recall: 0.9461 - accuracy: 0.9595 - val_loss: 0.2812 - val_iou: 0.9048 - val_dice_coef: 0.7109 - val_precision: 0.9268 - val_recall: 0.8025 - val_accuracy: 0.9083
# Epoch 98/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2102 - iou: 0.9317 - dice_coef: 0.7458 - precision: 0.9316 - recall: 0.9440 - accuracy: 0.9591 - val_loss: 0.2724 - val_iou: 0.9079 - val_dice_coef: 0.7270 - val_precision: 0.9025 - val_recall: 0.8462 - val_accuracy: 0.9126
# Epoch 99/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.2039 - iou: 0.9350 - dice_coef: 0.7479 - precision: 0.9384 - recall: 0.9451 - accuracy: 0.9638 - val_loss: 0.2679 - val_iou: 0.9098 - val_dice_coef: 0.7331 - val_precision: 0.8982 - val_recall: 0.8642 - val_accuracy: 0.9157
# Epoch 100/100
# 121/121 [==============================] - 3s 22ms/step - loss: 0.1880 - iou: 0.9435 - dice_coef: 0.7640 - precision: 0.9519 - recall: 0.9618 - accuracy: 0.9729 - val_loss: 0.2659 - val_iou: 0.9098 - val_dice_coef: 0.7365 - val_precision: 0.8894 - val_recall: 0.8792 - val_accuracy: 0.9167

# %% [markdown]
# ### Plotting Training Statistics

# %%
plt.figure(figsize=(14, 35))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(8,2,1)
plt.plot(hist_2.history['loss'], 'red')
plt.title('Training Loss for SegNet')
plt.subplot(8,2,2)
plt.plot(hist_2.history['accuracy'], 'green')
plt.title('Training Accuracy for SegNet')
plt.subplot(8,2,5)
plt.plot(hist.history['loss'], 'red')
plt.title('Training Loss for Unet')
plt.subplot(8,2,6)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Training Accuracy for Unet')
plt.subplot(8,2,3)
plt.plot(hist_2.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss for SegNet')
plt.subplot(8,2,4)
plt.plot(hist_2.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy for SegNet')
plt.subplot(8,2,7)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss for Unet')
plt.subplot(8,2,8)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy for Unet')
plt.show()

# %% [markdown]
# ### Loading the models for evaluation

# %% [markdown]
# For Unet

# %%
dropout_val=0.50
if K.common.image_dim_ordering() == 'th':
    inputs = Input((INPUT_CHANNELS, 192, 256))
    axis = 1
else:
    inputs = Input((192, 256, INPUT_CHANNELS))
    axis = 3
filters = 32

conv_224 = double_conv_layer(inputs, filters)
pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

conv_112 = double_conv_layer(pool_112, 2*filters)
pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

conv_56 = double_conv_layer(pool_56, 4*filters)
pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

conv_28 = double_conv_layer(pool_28, 8*filters)
pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

conv_14 = double_conv_layer(pool_14, 16*filters)
pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

conv_7 = double_conv_layer(pool_7, 32*filters)

up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
up_conv_14 = double_conv_layer(up_14, 16*filters)

up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
up_conv_28 = double_conv_layer(up_28, 8*filters)

up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
up_conv_56 = double_conv_layer(up_56, 4*filters)

up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
up_conv_112 = double_conv_layer(up_112, 2*filters)

up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
conv_final = Activation('sigmoid')(conv_final)
pred = Reshape((192, 256))(conv_final)

# %%
model_unet = Model(inputs, pred, name="UNET")
model_unet.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coef, precision, recall, accuracy])

# %%
model_unet.load_weights('unet_100_epoch.h5')

# %% [markdown]
# For SegNet

# %%
# Encoding layer
img_input = Input(shape= (192, 256, 3))
x = Conv2D(64, (3, 3), padding='same', name='conv1',strides= (1,1))(img_input)
x = BatchNormalization(name='bn1')(x)
x = Activation('relu')(x)
x = Conv2D(64, (3, 3), padding='same', name='conv2')(x)
x = BatchNormalization(name='bn2')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(128, (3, 3), padding='same', name='conv3')(x)
x = BatchNormalization(name='bn3')(x)
x = Activation('relu')(x)
x = Conv2D(128, (3, 3), padding='same', name='conv4')(x)
x = BatchNormalization(name='bn4')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(256, (3, 3), padding='same', name='conv5')(x)
x = BatchNormalization(name='bn5')(x)
x = Activation('relu')(x)
x = Conv2D(256, (3, 3), padding='same', name='conv6')(x)
x = BatchNormalization(name='bn6')(x)
x = Activation('relu')(x)
x = Conv2D(256, (3, 3), padding='same', name='conv7')(x)
x = BatchNormalization(name='bn7')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(512, (3, 3), padding='same', name='conv8')(x)
x = BatchNormalization(name='bn8')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv9')(x)
x = BatchNormalization(name='bn9')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv10')(x)
x = BatchNormalization(name='bn10')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Conv2D(512, (3, 3), padding='same', name='conv11')(x)
x = BatchNormalization(name='bn11')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv12')(x)
x = BatchNormalization(name='bn12')(x)
x = Activation('relu')(x)
x = Conv2D(512, (3, 3), padding='same', name='conv13')(x)
x = BatchNormalization(name='bn13')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Dense(1024, activation = 'relu', name='fc1')(x)
x = Dense(1024, activation = 'relu', name='fc2')(x)
# Decoding Layer 
x = UpSampling2D()(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv1')(x)
x = BatchNormalization(name='bn14')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv2')(x)
x = BatchNormalization(name='bn15')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv3')(x)
x = BatchNormalization(name='bn16')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv4')(x)
x = BatchNormalization(name='bn17')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(512, (3, 3), padding='same', name='deconv5')(x)
x = BatchNormalization(name='bn18')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv6')(x)
x = BatchNormalization(name='bn19')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv7')(x)
x = BatchNormalization(name='bn20')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv8')(x)
x = BatchNormalization(name='bn21')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv9')(x)
x = BatchNormalization(name='bn22')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv10')(x)
x = BatchNormalization(name='bn23')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv11')(x)
x = BatchNormalization(name='bn24')(x)
x = Activation('relu')(x)

x = UpSampling2D()(x)
x = Conv2DTranspose(64, (3, 3), padding='same', name='deconv12')(x)
x = BatchNormalization(name='bn25')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv13')(x)
x = BatchNormalization(name='bn26')(x)
x = Activation('sigmoid')(x)
pred = Reshape((192,256))(x)

# %%
model_segnet = Model(inputs=img_input, outputs=pred)

model_segnet.compile(optimizer= SGD(lr=0.001, momentum=0.9, decay=0.0005, nesterov=False), loss= ["binary_crossentropy"]
              , metrics=[iou, dice_coef, precision, recall, accuracy])

# %%
model_segnet.load_weights('segnet_100_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res_unet = model_unet.evaluate(x_train, y_train, batch_size= 18)
res_segnet = model_segnet.evaluate(x_train, y_train, batch_size= 18)
print('_______________SegNet_____Unet____')
print('IOU:       |   {:.2f}  |   {:.2f}  |'.format(res_segnet[1]*100, res_unet[1] * 100))
print('Dice Coef: |   {:.2f}  |   {:.2f}  |'.format(res_segnet[2]*100, res_unet[2] * 100))
print('Precision: |   {:.2f}  |   {:.2f}  |'.format(res_segnet[3]*100, res_unet[3] * 100))
print('Recall:    |   {:.2f}  |   {:.2f}  |'.format(res_segnet[4]*100, res_unet[4] * 100))
print('Accuracy:  |   {:.2f}  |   {:.2f}  |'.format(res_segnet[5]*100, res_unet[5] * 100))
print("Loss:      |   {:.2f}  |   {:.2f}  |".format(res_segnet[0]*100, res_unet[0] * 100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res_unet = model_unet.evaluate(x_test, y_test, batch_size= 18)
res_segnet = model_segnet.evaluate(x_test, y_test, batch_size= 18)
print('_______________SegNet_____Unet____')
print('IOU:       |   {:.2f}  |   {:.2f}  |'.format(res_segnet[1]*100, res_unet[1] * 100))
print('Dice Coef: |   {:.2f}  |   {:.2f}  |'.format(res_segnet[2]*100, res_unet[2] * 100))
print('Precision: |   {:.2f}  |   {:.2f}  |'.format(res_segnet[3]*100, res_unet[3] * 100))
print('Recall:    |   {:.2f}  |   {:.2f}  |'.format(res_segnet[4]*100, res_unet[4] * 100))
print('Accuracy:  |   {:.2f}  |   {:.2f}  |'.format(res_segnet[5]*100, res_unet[5] * 100))
print("Loss:      |   {:.2f}  |   {:.2f}  |".format(res_segnet[0]*100, res_unet[0] * 100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res_unet = model_unet.evaluate(x_val, y_val, batch_size= 18)
res_segnet = model_segnet.evaluate(x_val, y_val, batch_size= 18)
print('_______________SegNet_____Unet____')
print('IOU:       |   {:.2f}  |   {:.2f}  |'.format(res_segnet[1]*100, res_unet[1] * 100))
print('Dice Coef: |   {:.2f}  |   {:.2f}  |'.format(res_segnet[2]*100, res_unet[2] * 100))
print('Precision: |   {:.2f}  |   {:.2f}  |'.format(res_segnet[3]*100, res_unet[3] * 100))
print('Recall:    |   {:.2f}  |   {:.2f}  |'.format(res_segnet[4]*100, res_unet[4] * 100))
print('Accuracy:  |   {:.2f}  |   {:.2f}  |'.format(res_segnet[5]*100, res_unet[5] * 100))
print("Loss:      |   {:.2f}  |   {:.2f}  |".format(res_segnet[0]*100, res_unet[0] * 100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 121/121 [==============================] - 2s 15ms/step
# 121/121 [==============================] - 3s 21ms/step
# _______________SegNet_____Unet____
# IOU:       |   93.80  |   91.19  |
# Dice Coef: |   75.41  |   81.78  |
# Precision: |   92.41  |   90.25  |
# Recall:    |   96.62  |   79.13  |
# Accuracy:  |   96.60  |   90.94  |
# Loss:      |   19.63  |   8.81  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 1s 14ms/step
# 50/50 [==============================] - 1s 17ms/step
# _______________SegNet_____Unet____
# IOU:       |   90.32  |   91.73  |
# Dice Coef: |   71.68  |   83.61  |
# Precision: |   83.54  |   89.49  |
# Recall:    |   91.59  |   83.20  |
# Accuracy:  |   91.93  |   91.83  |
# Loss:      |   26.45  |   8.27  |
# ________________________
#
# -------------On validation Set---------------------
#
# 31/31 [==============================] - 0s 4ms/step
# 31/31 [==============================] - 0s 8ms/step
# _______________SegNet_____Unet____
# IOU:       |   90.98  |   91.07  |
# Dice Coef: |   73.65  |   82.57  |
# Precision: |   88.94  |   93.29  |
# Recall:    |   87.92  |   78.51  |
# Accuracy:  |   91.67  |   90.32  |
# Loss:      |   26.59  |   8.93  |
# ________________________

# %% [markdown]
# ## Visualising Predicted Lesions

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred1 = model_unet.predict(x_test[img_num].reshape(1,192,256,3))
img_pred2 = model_segnet.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(20,16))
plt.subplot(1,4,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,4,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,4,3)
plt.imshow(img_pred1.reshape(192, 256), plt.cm.binary_r)
plt.title('Unet Prediction Output')
plt.subplot(1,4,4)
plt.imshow(img_pred2.reshape(192, 256), plt.cm.binary_r)
plt.title('SegNet Prediction Output')
plt.show()

# %%
img_num = 48
img_pred1 = model_unet.predict(x_test[img_num].reshape(1,192,256,3))
img_pred2 = model_segnet.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(20,16))
plt.subplot(1,4,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,4,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,4,3)
plt.imshow(img_pred1.reshape(192, 256), plt.cm.binary_r)
plt.title('Unet Prediction Output')
plt.subplot(1,4,4)
plt.imshow(img_pred2.reshape(192, 256), plt.cm.binary_r)
plt.title('SegNet Prediction Output')
plt.show()

# %%
img_num = 29
img_pred1 = model_unet.predict(x_test[img_num].reshape(1,192,256,3))
img_pred2 = model_segnet.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(20,16))
plt.subplot(1,4,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,4,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,4,3)
plt.imshow(img_pred1.reshape(192, 256), plt.cm.binary_r)
plt.title('Unet Prediction Output')
plt.subplot(1,4,4)
plt.imshow(img_pred2.reshape(192, 256), plt.cm.binary_r)
plt.title('SegNet Prediction Output')
plt.show()

# %%
img_num = 21
img_pred1 = model_unet.predict(x_test[img_num].reshape(1,192,256,3))
img_pred2 = model_segnet.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(20,16))
plt.subplot(1,4,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,4,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,4,3)
plt.imshow(img_pred1.reshape(192, 256), plt.cm.binary_r)
plt.title('Unet Prediction Output')
plt.subplot(1,4,4)
plt.imshow(img_pred2.reshape(192, 256), plt.cm.binary_r)
plt.title('SegNet Prediction Output')
plt.show()

# %%
img_num = 11
img_pred1 = model_unet.predict(x_test[img_num].reshape(1,192,256,3))
img_pred2 = model_segnet.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(20,16))
plt.subplot(1,4,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,4,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,4,3)
plt.imshow(img_pred1.reshape(192, 256), plt.cm.binary_r)
plt.title('Unet Prediction Output')
plt.subplot(1,4,4)
plt.imshow(img_pred2.reshape(192, 256), plt.cm.binary_r)
plt.title('SegNet Prediction Output')
plt.show()

# %% [markdown]
# ### Ensemble

# %% [markdown]
# ## Bagging
#
# Bagging is a technique in which the results of the different models are averaged out to get more accurate results. We will manually implement this technique for each pixel.
#
# ## Post Processing
# A simple post processing technique we will use is thresholding. Using a threshold of 0.7 which is an arbitrary value chosen from different values tried practically. Pixel having value greater than 0.7 will be changed to 1 whiile less than it will be switched to 0. This will also remove a lot of gray pixels.

# %%
def enhance(img):
    sub1 = (model_unet.predict(img.reshape(1,192,256,3))).flatten()
    sub2 = (model_segnet.predict(img.reshape(1,192,256,3))).flatten()
    sub = sub1[:]
    for i in range(len(sub)):
        sub[i] = (sub1[i] + sub2[i])/2
        
        if sub[i] > 0.7:
            sub[i] = 1
        else:
            sub[i] = 0

    return sub

# %%
plt.figure(figsize=(25,16))
plt.suptitle('Comparing the Prediction after enhancement')

img_num = 48
plt.subplot(4,4,1)
plt.imshow(y_test[img_num],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(4,4,2)

img_pred1 = model_unet.predict(x_test[img_num].reshape(1,192,256,3))
img_pred2 = model_segnet.predict(x_test[img_num].reshape(1,192,256,3))

plt.imshow(img_pred1.reshape(192,256), plt.cm.binary_r)
plt.title('Unet Predicted')
plt.subplot(4,4,3)
plt.imshow(img_pred2.reshape(192,256), plt.cm.binary_r)
plt.title('SegNet Predicted')
plt.subplot(4,4,4)
plt.imshow(enhance(x_test[img_num]).reshape(192,256), plt.cm.binary_r)
plt.title('Ensemble Output')


img_num = 37
plt.subplot(4,4,5)
plt.imshow(y_test[img_num],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(4,4,6)

img_pred1 = model_unet.predict(x_test[img_num].reshape(1,192,256,3))
img_pred2 = model_segnet.predict(x_test[img_num].reshape(1,192,256,3))

plt.imshow(img_pred1.reshape(192,256), plt.cm.binary_r)
plt.title('Unet Predicted')
plt.subplot(4,4,7)
plt.imshow(img_pred2.reshape(192,256), plt.cm.binary_r)
plt.title('SegNet Predicted')
plt.subplot(4,4,8)
plt.imshow(enhance(x_test[img_num]).reshape(192,256), plt.cm.binary_r)
plt.title('Ensemble Output')

img_num = 11
plt.subplot(4,4,9)
plt.imshow(y_test[img_num],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(4,4,10)

img_pred1 = model_unet.predict(x_test[img_num].reshape(1,192,256,3))
img_pred2 = model_segnet.predict(x_test[img_num].reshape(1,192,256,3))

plt.imshow(img_pred1.reshape(192,256), plt.cm.binary_r)
plt.title('Unet Predicted')
plt.subplot(4,4,11)
plt.imshow(img_pred2.reshape(192,256), plt.cm.binary_r)
plt.title('SegNet Predicted')
plt.subplot(4,4,12)
plt.imshow(enhance(x_test[img_num]).reshape(192,256), plt.cm.binary_r)
plt.title('Ensemble Output')

img_num = 49
plt.subplot(4,4,13)
plt.imshow(y_test[img_num],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(4,4,14)

img_pred1 = model_unet.predict(x_test[img_num].reshape(1,192,256,3))
img_pred2 = model_segnet.predict(x_test[img_num].reshape(1,192,256,3))

plt.imshow(img_pred1.reshape(192,256), plt.cm.binary_r)
plt.title('Unet Predicted')
plt.subplot(4,4,15)
plt.imshow(img_pred2.reshape(192,256), plt.cm.binary_r)
plt.title('SegNet Predicted')
plt.subplot(4,4,16)
plt.imshow(enhance(x_test[img_num]).reshape(192,256), plt.cm.binary_r)
plt.title('Ensemble Output')
plt.show()

# %% [markdown]
# # **So we can see that our ensembled results have a good balance of more accurate boundaries of unet and less noisy predictions of SegNet**
